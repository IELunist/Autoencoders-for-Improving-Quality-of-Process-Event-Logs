# %%
import importlib
import argparse
import os, sys
import argparse
import pandas as pd
import numpy as np
import pickle
import time

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, roc_curve, auc, precision_recall_curve


# %matplotlib inline

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.optim as optim
from torch.nn.utils import clip_grad_norm

# %%
sys.path.insert(0, './../utils/')
from utils import *
from models import *

# %%
#Define parser
#name = 'bpi_2012'
#name = 'bpi_2013'
name = 'small_log'
#name = 'large_log'

parser = {
    'train': True,
    'test': True,
    'model_class': 'GRUAE',
    'model_name': '',
    'data_dir': '../data/',
    'data_file': name + '.csv',
    'anomaly_pct': 0.1,
    'scaler': 'standardization',
    'input_dir': '../input/{}/'.format(name), 
    'batch_size' : 16,
    'epochs' : 100,
    'no_cuda' : False,
    'seed' : 7,
    'clip': 0.25,
    'layer1': 5,
    'lr': 0.001,
    'betas': (0.9, 0.999),   
    'lr_decay': 0.99,
}

args = argparse.Namespace(**parser)
args.output_dir = './output/{0}_{1}_{2}/'.format(name, args.anomaly_pct, args.model_class)

# %%
if not os.path.isdir(args.output_dir):
    os.makedirs(args.output_dir)

# %%
args.cuda = not args.no_cuda and torch.cuda.is_available()
kwargs = {'num_workers': 2, 'pin_memory': True} if args.cuda else {}

# %%
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)

# %%
preprocessed_data_name = os.path.join(args.input_dir, 'preprocessed_data_{}.pkl'.format(args.anomaly_pct))
with open(preprocessed_data_name, 'rb') as f:
    input_train = pickle.load(f)
    input_val = pickle.load(f)
    input_test = pickle.load(f)
    pad_index_train = pickle.load(f)
    pad_index_val = pickle.load(f)
    pad_index_test = pickle.load(f)
    activity_label_test = pickle.load(f)
    time_label_test = pickle.load(f)
    train_case_num = pickle.load(f)
    val_case_num = pickle.load(f)
    test_case_num = pickle.load(f)
    train_row_num = pickle.load(f)
    val_row_num = pickle.load(f)
    test_row_num = pickle.load(f)
    min_value = pickle.load(f)
    max_value = pickle.load(f)
    mean_value = pickle.load(f)
    std_value = pickle.load(f)
    cols = pickle.load(f)
    statistics_storage = pickle.load(f)
    true_time = pickle.load(f)
    true_act = pickle.load(f)
    full_true_time = pickle.load(f)
    full_true_act = pickle.load(f)

# %% [markdown]
# # Load data

# %%
#train
input_trainLoader = torch.utils.data.DataLoader(input_train, batch_size=args.batch_size, shuffle=False, num_workers=2)
pad_index_trainLoader = torch.utils.data.DataLoader(pad_index_train, batch_size=args.batch_size, shuffle=False, num_workers=2)

# %%
#df
normal_df_name = os.path.join(args.input_dir, 'normal_df_{}.csv'.format(args.anomaly_pct))
normal_df = pd.read_csv(normal_df_name)

anomalous_df_name = os.path.join(args.input_dir, 'anomolous_df_{}.csv'.format(args.anomaly_pct))
anomalous_df = pd.read_csv(anomalous_df_name)

#test
caseid_test = normal_df['CaseID'][-test_row_num:]
normal_df_test = normal_df[-test_row_num:]
anomalous_df_test = anomalous_df[-test_row_num:]

# %% [markdown]
# # Build model

# %% [markdown]
# ## Define model

# %%
if args.model_class == 'GRUAE':
    model = GRUAE(input_train.shape[2], args.layer1, 1, args.cuda)

if args.cuda:
    model.cuda()

# %%
model.parameters
# Out:
# <bound method Module.parameters of GRUAE (
#   (encoder): EncoderGRU (
#     (gru): GRU(15, 5, batch_first=True)
#   )
#   (decoder): DecoderGRU (
#     (gru): GRU(5, 5, batch_first=True)
#     (linear): Linear (5 -> 15)
#   )
# )>

# %% [markdown]
# ## Define loss

# %%
def loss_function(recon_x, x, pad_index):
    MSE = F.mse_loss(recon_x*pad_index, x*pad_index, size_average=False) 
    return MSE

# %% [markdown]
# ## Define optimizer

# %%
optimizer = optim.Adam(model.parameters(), lr=args.lr, betas=args.betas)

# %%
#Adjust learning rate per epoch: http://pytorch.org/docs/master/optim.html?highlight=adam#torch.optim.Adam

# Method 1:
lambda1 = lambda epoch: args.lr_decay ** epoch
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=[lambda1])

# Method 2:
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=10)

# %%
#torch.nn.utils.clip_grad_norm(model.parameters(), args.clip)

# %% [markdown]
# # Utils

# %%
def save_model(model, epoch, score):
    model_file = os.path.join(args.output_dir, 'model_{}_epoch{}_score{:.4f}.pth'.format(args.model_class, epoch, score))
    torch.save(model.state_dict(), model_file)

# %%
def load_model(model, model_name):
    model_file = os.path.join(args.output_dir, model_name)
    assert os.path.isfile(model_file), 'Error: no model found!'
    model_state = torch.load(model_file)
    model.load_state_dict(model_state)

# %%
def val(model, input_val, pad_index_val):
    model.eval()
    input_val = Variable(torch.Tensor(input_val).float())
    pad_index_val = Variable(torch.Tensor(pad_index_val).float())
    
    if args.cuda:
        input_val = input_val.cuda()
        pad_index_val = pad_index_val.cuda()
    
    recon_val = model(input_val)    
    loss = loss_function(recon_val, input_val, pad_index_val)
    return loss.data[0]/len(input_test.data)

# %% [markdown]
# # Train

# %%
def train(epoch, model, optimizer):
    model.train()
    train_loss = 0
    for batch_idx, (batch_data, batch_index) in enumerate(zip(input_trainLoader, pad_index_trainLoader)):
        
        batch_data = Variable(batch_data.float())
        batch_index = Variable(batch_index.float())

        if args.cuda:
            batch_data = batch_data.cuda()
            batch_index = batch_index.cuda()
            
        optimizer.zero_grad()
        
        recon_data = model(batch_data)
        
        loss = loss_function(recon_data, batch_data, batch_index)
        
        loss.backward()
        train_loss += loss.data[0]
        optimizer.step()
        
    return train_loss / len(input_trainLoader.dataset)

# %%
if args.train:
    for epoch in range(1, args.epochs + 1):
        init = time.time()
        
        #method 1 scheduler
        scheduler.step()
        
        train_loss = train(epoch, model, optimizer)
        end_train = time.time()
        val_score = val(model, input_val, pad_index_val)
        
        end = time.time()
        print('====> Epoch {} | Train time: {:.4f} ms| End time: {:.4f} ms | Train loss: {:.4f} | Val loss: {:.4f}'.
              format(epoch, (end_train-init)*1000, (end-init)*1000, train_loss, val_score))
else:
    load_model(model, args.model_name)
# Out:
# ====> Epoch 1 | Train time: 442.4629 ms| End time: 452.3683 ms | Train loss: 51.3988 | Val loss: 36.4933
# ====> Epoch 2 | Train time: 324.6603 ms| End time: 333.9224 ms | Train loss: 32.8395 | Val loss: 30.0295
# ====> Epoch 3 | Train time: 322.4220 ms| End time: 332.5465 ms | Train loss: 28.1503 | Val loss: 26.4268
# ====> Epoch 4 | Train time: 327.1556 ms| End time: 336.5338 ms | Train loss: 25.0211 | Val loss: 23.5921
# ====> Epoch 5 | Train time: 323.2965 ms| End time: 337.9564 ms | Train loss: 22.2336 | Val loss: 20.7181
# ====> Epoch 6 | Train time: 324.6422 ms| End time: 339.3905 ms | Train loss: 19.2195 | Val loss: 17.5586
# ====> Epoch 7 | Train time: 326.8347 ms| End time: 336.1464 ms | Train loss: 16.1684 | Val loss: 14.7535
# ====> Epoch 8 | Train time: 326.3559 ms| End time: 340.6498 ms | Train loss: 13.8547 | Val loss: 12.9762
# ====> Epoch 9 | Train time: 323.1032 ms| End time: 332.4029 ms | Train loss: 12.5284 | Val loss: 12.0409
# ====> Epoch 10 | Train time: 326.1418 ms| End time: 340.6034 ms | Train loss: 11.8280 | Val loss: 11.5269
# ====> Epoch 11 | Train time: 319.7556 ms| End time: 334.0139 ms | Train loss: 11.4154 | Val loss: 11.1926
# ====> Epoch 12 | Train time: 326.6287 ms| End time: 336.8797 ms | Train loss: 11.1292 | Val loss: 10.9431
# ====> Epoch 13 | Train time: 328.2504 ms| End time: 337.5671 ms | Train loss: 10.9084 | Val loss: 10.7434
# ====> Epoch 14 | Train time: 323.1168 ms| End time: 332.5498 ms | Train loss: 10.7283 | Val loss: 10.5776
# ====> Epoch 15 | Train time: 323.7202 ms| End time: 337.9786 ms | Train loss: 10.5762 | Val loss: 10.4363
# ====> Epoch 16 | Train time: 321.2469 ms| End time: 335.7649 ms | Train loss: 10.4442 | Val loss: 10.3130
# ====> Epoch 17 | Train time: 320.3523 ms| End time: 334.7189 ms | Train loss: 10.3269 | Val loss: 10.2028
# ====> Epoch 18 | Train time: 325.0830 ms| End time: 334.6384 ms | Train loss: 10.2203 | Val loss: 10.1020
# ====> Epoch 19 | Train time: 327.0946 ms| End time: 336.4899 ms | Train loss: 10.1216 | Val loss: 10.0080
# ====> Epoch 20 | Train time: 326.7264 ms| End time: 336.0655 ms | Train loss: 10.0286 | Val loss: 9.9188
# ====> Epoch 21 | Train time: 325.3758 ms| End time: 334.6746 ms | Train loss: 9.9399 | Val loss: 9.8331
# ====> Epoch 22 | Train time: 322.7482 ms| End time: 337.3265 ms | Train loss: 9.8542 | Val loss: 9.7494
# ====> Epoch 23 | Train time: 324.6646 ms| End time: 339.4659 ms | Train loss: 9.7702 | Val loss: 9.6669
# ====> Epoch 24 | Train time: 325.1307 ms| End time: 334.4631 ms | Train loss: 9.6874 | Val loss: 9.5853
# ====> Epoch 25 | Train time: 325.1033 ms| End time: 339.7465 ms | Train loss: 9.6055 | Val loss: 9.5046
# ====> Epoch 26 | Train time: 319.9618 ms| End time: 334.2316 ms | Train loss: 9.5249 | Val loss: 9.4257
# ====> Epoch 27 | Train time: 320.9894 ms| End time: 335.4411 ms | Train loss: 9.4467 | Val loss: 9.3497
# ====> Epoch 28 | Train time: 322.4337 ms| End time: 337.2777 ms | Train loss: 9.3722 | Val loss: 9.2780
# ====> Epoch 29 | Train time: 322.5117 ms| End time: 336.8287 ms | Train loss: 9.3028 | Val loss: 9.2118
# ====> Epoch 30 | Train time: 321.3909 ms| End time: 330.8797 ms | Train loss: 9.2395 | Val loss: 9.1521
# ====> Epoch 31 | Train time: 330.3211 ms| End time: 339.5650 ms | Train loss: 9.1829 | Val loss: 9.0992
# ====> Epoch 32 | Train time: 326.3912 ms| End time: 340.7359 ms | Train loss: 9.1332 | Val loss: 9.0528
# ====> Epoch 33 | Train time: 324.3835 ms| End time: 333.7808 ms | Train loss: 9.0897 | Val loss: 9.0125
# ====> Epoch 34 | Train time: 322.9065 ms| End time: 337.4586 ms | Train loss: 9.0519 | Val loss: 8.9774
# ====> Epoch 35 | Train time: 320.7469 ms| End time: 335.6817 ms | Train loss: 9.0190 | Val loss: 8.9467
# ====> Epoch 36 | Train time: 320.4732 ms| End time: 334.7130 ms | Train loss: 8.9901 | Val loss: 8.9197
# ====> Epoch 37 | Train time: 324.4243 ms| End time: 333.7879 ms | Train loss: 8.9644 | Val loss: 8.8957
# ====> Epoch 38 | Train time: 319.8888 ms| End time: 329.5250 ms | Train loss: 8.9415 | Val loss: 8.8742
# ====> Epoch 39 | Train time: 333.6334 ms| End time: 348.3648 ms | Train loss: 8.9209 | Val loss: 8.8548
# ====> Epoch 40 | Train time: 323.3082 ms| End time: 337.4984 ms | Train loss: 8.9021 | Val loss: 8.8371
# ====> Epoch 41 | Train time: 325.8612 ms| End time: 340.6329 ms | Train loss: 8.8848 | Val loss: 8.8208
# ====> Epoch 42 | Train time: 321.8956 ms| End time: 336.3802 ms | Train loss: 8.8690 | Val loss: 8.8058
# ====> Epoch 43 | Train time: 325.8436 ms| End time: 336.0908 ms | Train loss: 8.8542 | Val loss: 8.7918
# ====> Epoch 44 | Train time: 323.4477 ms| End time: 337.9402 ms | Train loss: 8.8405 | Val loss: 8.7789
# ====> Epoch 45 | Train time: 325.7720 ms| End time: 334.9280 ms | Train loss: 8.8277 | Val loss: 8.7667
# ====> Epoch 46 | Train time: 326.2916 ms| End time: 340.9083 ms | Train loss: 8.8157 | Val loss: 8.7553
# ====> Epoch 47 | Train time: 328.0325 ms| End time: 342.3090 ms | Train loss: 8.8044 | Val loss: 8.7446
# ====> Epoch 48 | Train time: 323.9610 ms| End time: 333.3211 ms | Train loss: 8.7938 | Val loss: 8.7344
# ====> Epoch 49 | Train time: 324.2052 ms| End time: 338.7277 ms | Train loss: 8.7837 | Val loss: 8.7248
# ====> Epoch 50 | Train time: 328.5921 ms| End time: 338.0942 ms | Train loss: 8.7742 | Val loss: 8.7157
# ====> Epoch 51 | Train time: 322.9272 ms| End time: 332.2456 ms | Train loss: 8.7651 | Val loss: 8.7070
# ====> Epoch 52 | Train time: 329.9065 ms| End time: 344.8024 ms | Train loss: 8.7564 | Val loss: 8.6987
# ====> Epoch 53 | Train time: 329.7119 ms| End time: 339.1500 ms | Train loss: 8.7481 | Val loss: 8.6907
# ====> Epoch 54 | Train time: 326.2992 ms| End time: 340.9169 ms | Train loss: 8.7402 | Val loss: 8.6831
# ====> Epoch 55 | Train time: 324.2059 ms| End time: 333.6396 ms | Train loss: 8.7326 | Val loss: 8.6758
# ====> Epoch 56 | Train time: 327.4720 ms| End time: 341.8334 ms | Train loss: 8.7253 | Val loss: 8.6687
# ====> Epoch 57 | Train time: 324.0414 ms| End time: 338.6502 ms | Train loss: 8.7182 | Val loss: 8.6619
# ====> Epoch 58 | Train time: 324.9700 ms| End time: 339.8235 ms | Train loss: 8.7113 | Val loss: 8.6553
# ====> Epoch 59 | Train time: 324.2013 ms| End time: 338.7413 ms | Train loss: 8.7047 | Val loss: 8.6489
# ====> Epoch 60 | Train time: 322.5584 ms| End time: 331.9864 ms | Train loss: 8.6983 | Val loss: 8.6427
# ====> Epoch 61 | Train time: 328.7821 ms| End time: 338.1348 ms | Train loss: 8.6920 | Val loss: 8.6366
# ====> Epoch 62 | Train time: 327.3008 ms| End time: 336.8070 ms | Train loss: 8.6859 | Val loss: 8.6307
# ====> Epoch 63 | Train time: 329.5431 ms| End time: 339.7806 ms | Train loss: 8.6800 | Val loss: 8.6249
# ====> Epoch 64 | Train time: 327.3423 ms| End time: 337.1382 ms | Train loss: 8.6741 | Val loss: 8.6192
# ====> Epoch 65 | Train time: 324.9695 ms| End time: 339.4103 ms | Train loss: 8.6684 | Val loss: 8.6137
# ====> Epoch 66 | Train time: 322.9885 ms| End time: 337.9891 ms | Train loss: 8.6627 | Val loss: 8.6082
# ====> Epoch 67 | Train time: 331.4900 ms| End time: 346.4897 ms | Train loss: 8.6572 | Val loss: 8.6028
# ====> Epoch 68 | Train time: 323.5130 ms| End time: 337.8603 ms | Train loss: 8.6517 | Val loss: 8.5975
# ====> Epoch 69 | Train time: 327.0714 ms| End time: 341.3887 ms | Train loss: 8.6462 | Val loss: 8.5922
# ====> Epoch 70 | Train time: 325.3105 ms| End time: 334.6310 ms | Train loss: 8.6408 | Val loss: 8.5870
# ====> Epoch 71 | Train time: 321.0266 ms| End time: 335.5997 ms | Train loss: 8.6354 | Val loss: 8.5818
# ====> Epoch 72 | Train time: 325.4042 ms| End time: 339.8929 ms | Train loss: 8.6300 | Val loss: 8.5766
# ====> Epoch 73 | Train time: 325.6557 ms| End time: 340.1518 ms | Train loss: 8.6246 | Val loss: 8.5714
# ====> Epoch 74 | Train time: 323.2782 ms| End time: 332.6843 ms | Train loss: 8.6193 | Val loss: 8.5662
# ====> Epoch 75 | Train time: 326.3326 ms| End time: 335.7933 ms | Train loss: 8.6138 | Val loss: 8.5610
# ====> Epoch 76 | Train time: 328.8350 ms| End time: 343.2002 ms | Train loss: 8.6084 | Val loss: 8.5557
# ====> Epoch 77 | Train time: 323.4742 ms| End time: 337.7719 ms | Train loss: 8.6028 | Val loss: 8.5504
# ====> Epoch 78 | Train time: 323.7696 ms| End time: 338.4860 ms | Train loss: 8.5972 | Val loss: 8.5449
# ====> Epoch 79 | Train time: 321.3592 ms| End time: 330.9577 ms | Train loss: 8.5914 | Val loss: 8.5394
# ====> Epoch 80 | Train time: 327.2390 ms| End time: 341.8052 ms | Train loss: 8.5855 | Val loss: 8.5337
# ====> Epoch 81 | Train time: 337.0922 ms| End time: 346.5266 ms | Train loss: 8.5794 | Val loss: 8.5279
# ====> Epoch 82 | Train time: 328.8751 ms| End time: 338.2430 ms | Train loss: 8.5731 | Val loss: 8.5218
# ====> Epoch 83 | Train time: 326.4725 ms| End time: 340.8573 ms | Train loss: 8.5665 | Val loss: 8.5155
# ====> Epoch 84 | Train time: 323.7178 ms| End time: 333.3452 ms | Train loss: 8.5597 | Val loss: 8.5090
# ====> Epoch 85 | Train time: 325.6757 ms| End time: 335.1948 ms | Train loss: 8.5525 | Val loss: 8.5021
# ====> Epoch 86 | Train time: 324.1789 ms| End time: 333.9343 ms | Train loss: 8.5449 | Val loss: 8.4948
# ====> Epoch 87 | Train time: 324.1911 ms| End time: 338.6781 ms | Train loss: 8.5369 | Val loss: 8.4872
# ====> Epoch 88 | Train time: 319.7491 ms| End time: 329.2551 ms | Train loss: 8.5285 | Val loss: 8.4792
# ====> Epoch 89 | Train time: 326.9458 ms| End time: 341.2580 ms | Train loss: 8.5196 | Val loss: 8.4707
# ====> Epoch 90 | Train time: 323.1637 ms| End time: 332.5291 ms | Train loss: 8.5103 | Val loss: 8.4618
# ====> Epoch 91 | Train time: 363.2925 ms| End time: 372.7238 ms | Train loss: 8.5004 | Val loss: 8.4524
# ====> Epoch 92 | Train time: 330.6344 ms| End time: 344.9667 ms | Train loss: 8.4902 | Val loss: 8.4426
# ====> Epoch 93 | Train time: 323.9768 ms| End time: 333.2675 ms | Train loss: 8.4795 | Val loss: 8.4323
# ====> Epoch 94 | Train time: 325.5210 ms| End time: 335.0809 ms | Train loss: 8.4684 | Val loss: 8.4217
# ====> Epoch 95 | Train time: 333.6585 ms| End time: 348.1050 ms | Train loss: 8.4570 | Val loss: 8.4108
# ====> Epoch 96 | Train time: 325.7756 ms| End time: 335.6376 ms | Train loss: 8.4453 | Val loss: 8.3997
# ====> Epoch 97 | Train time: 327.4467 ms| End time: 336.8661 ms | Train loss: 8.4336 | Val loss: 8.3884
# ====> Epoch 98 | Train time: 324.1506 ms| End time: 333.2186 ms | Train loss: 8.4218 | Val loss: 8.3772
# ====> Epoch 99 | Train time: 325.2358 ms| End time: 340.2233 ms | Train loss: 8.4101 | Val loss: 8.3662
# ====> Epoch 100 | Train time: 328.2530 ms| End time: 337.7602 ms | Train loss: 8.3986 | Val loss: 8.3554

# %% [markdown]
# # Predict

# %%
if args.test:
    input_test = Variable(torch.Tensor(input_test).float())
    if args.cuda:
        input_test = input_test.cuda()
    
    print('Predicting...')
    recon_test = model(input_test)
    
    print('Separating prediction ...')
    predicted_time, predicted_activity = getPrediction(recon_test, pad_index_test)
    
    print('Done!')
# Out:
# Predicting...
# Separating prediction ...
# Done!

# %% [markdown]
# # Evaluate

# %% [markdown]
# ## Time

# %%
#Fix predicted time
time_df = pd.DataFrame({'CaseID': caseid_test,
                        'PredictedTime': predicted_time})

groupByCase = time_df.groupby(['CaseID'])
fixed_time_df = pd.DataFrame(columns=list(time_df))

for case, group in groupByCase:
    group.iloc[0, 1] = -mean_value/std_value
    fixed_time_df = fixed_time_df.append(group)
# Out:
# /home/pllab/miniconda2/envs/pydata/lib/python3.5/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
fixed_predicted_time = fixed_time_df['PredictedTime']

# %%
error = np.abs(true_time - fixed_predicted_time)
error_time_df = pd.DataFrame({'Error': error,
                              'TimeLabel': time_label_test})

# %%
precision, recall, th = precision_recall_curve(error_time_df.TimeLabel, error_time_df.Error, pos_label=1)
plt.figure(figsize=(20, 5))
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
time_threshold = np.mean(error_time_df['Error'])
print('Threshold of Time: {}'.format(time_threshold))
# Out:
# Threshold of Time: 0.026305563858114986

# %%
plotOverlapReconstructionError(error_time_df, variable='Time', output_dir=args.output_dir, save=True)

# %%
plotReconstructionError(error_time_df, variable='Time')

# %%
plotConfusionMaxtrix(error_time_df, threshold=time_threshold, variable='Time', output_dir=args.output_dir, save=True)

# %%
evalScore(error_time_df, threshold=time_threshold, variable='Time')
# Out:
# -------Evaluation of Time-------
#
#
# --Weighted Evaluation--
# Evaluation of Time
# Precision: 0.90
# Recall: 0.77
# Fscore: 0.81
#
#
# --Evaluation for each class--
# Normal
# Precision: 0.96
# Recall: 0.78
# Fscore: 0.86
#
#
# Anomaly
# Precision: 0.24
# Recall: 0.71
# Fscore: 0.36

# %%
fpr, tpr, thresholds = roc_curve(error_time_df.TimeLabel, error_time_df.Error, pos_label=1)
roc_auc = auc(fpr, tpr)

#plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig(args.output_dir + 'ROC_time.png')
plt.show();

# %%
#get submission
if args.scaler == 'standardization':
    inverse_scaled_time = [x*std_value+mean_value for x in fixed_predicted_time]
else:
    inverse_scaled_time = [x*(max_value-min_value)+min_value for x in fixed_predicted_time]
    
predicted_time_label_test = [1 if e > time_threshold else 0 for e in error_time_df.Error.values]

submission_time = pd.DataFrame({'AnomalousDuration': anomalous_df_test['AnomalousDuration'].copy(),
                                'Activity': normal_df_test['Activity'].copy(),
                                'AnomalousCumDuration': anomalous_df_test['AnomalousCumDuration'].copy(),
                                'PredictedCumDuration': inverse_scaled_time,
                                'TimeLabel': time_label_test,
                                'PredictedTimeLabel': predicted_time_label_test})

# %%
submission_time.head()
# Out:
#          Activity  AnomalousCumDuration  AnomalousDuration  \
# 22400  Activity A                   0.0                0.0
# 22401  Activity B                3600.0             3600.0
# 22402  Activity C                7200.0             3600.0
# 22403  Activity D               10800.0             3600.0
# 22404  Activity E               14400.0             3600.0
#
#        PredictedCumDuration  PredictedTimeLabel TimeLabel
# 22400              0.000000                   0         0
# 22401           3638.452854                   0         0
# 22402           7182.092451                   0         0
# 22403          10685.282897                   0         0
# 22404          14504.309258                   0         0

# %%
groupByActivity = submission_time.groupby(['Activity'])

for act, group in groupByActivity:
    plotDurationofPredictedTimeLabel(act, group, statistics_storage, args.output_dir, True)

# %%
submission_time.head()
# Out:
#          Activity  AnomalousCumDuration  AnomalousDuration  \
# 22400  Activity A                   0.0                0.0
# 22401  Activity B                3600.0             3600.0
# 22402  Activity C                7200.0             3600.0
# 22403  Activity D               10800.0             3600.0
# 22404  Activity E               14400.0             3600.0
#
#        PredictedCumDuration  PredictedTimeLabel TimeLabel
# 22400              0.000000                   0         0
# 22401           3638.452854                   0         0
# 22402           7182.092451                   0         0
# 22403          10685.282897                   0         0
# 22404          14504.309258                   0         0

# %%
act_list = [i for i in submission_time['Activity'].unique()]
false_positive_df = submission_time[(submission_time['PredictedTimeLabel']== 1)&(submission_time['TimeLabel']== 0)]
false_negative_df = submission_time[(submission_time['PredictedTimeLabel']== 0)&(submission_time['TimeLabel']== 1)]

for act in act_list:
    plotFalseDuration(false_positive_df, false_negative_df, act, statistics_storage)

# %% [markdown]
# ## Activity

# %% [markdown]
# ### Threshold

# %%
# error = np.mean(np.power(true_act - predicted_activity, 2), axis = 1)
error = np.mean(np.abs(true_act - predicted_activity), axis = 1)
error_activity_df = pd.DataFrame({'Error': error,
                                  'ActivityLabel': activity_label_test})

# %%
error_activity_df.head()
# Out:
#        ActivityLabel     Error
# 22400              0  0.121850
# 22401              0  0.127856
# 22402              0  0.128112
# 22403              0  0.128787
# 22404              0  0.125059

# %%
precision, recall, th = precision_recall_curve(error_activity_df.ActivityLabel, error_activity_df.Error, pos_label=1)
plt.figure(figsize=(20, 5))
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
activity_threshold = np.mean(error_activity_df['Error'])
print('Threshold of Activity: {}'.format(activity_threshold))
# Out:
# Threshold of Activity: 0.12863365323487097

# %%
plotConfusionMaxtrix(error_activity_df, activity_threshold, variable='Activity', output_dir=args.output_dir, save=True)

# %%
plotOverlapReconstructionError(error_activity_df, variable='Activity', output_dir=args.output_dir, save=True)

# %%
plotReconstructionError(error_activity_df)

# %%
evalScore(error_activity_df, activity_threshold, variable='Activity')
# Out:
# -------Evaluation of Activity-------
#
#
# --Weighted Evaluation--
# Evaluation of Activity
# Precision: 0.88
# Recall: 0.53
# Fscore: 0.61
#
#
# --Evaluation for each class--
# Normal
# Precision: 0.96
# Recall: 0.49
# Fscore: 0.65
#
#
# Anomaly
# Precision: 0.16
# Recall: 0.83
# Fscore: 0.27

# %%
fpr, tpr, thresholds = roc_curve(error_activity_df.ActivityLabel, error_activity_df.Error, pos_label=1)
roc_auc = auc(fpr, tpr)

#plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig(args.output_dir+'ROC_Act.png')
plt.show();

# %% [markdown]
# ### Argmax

# %%
# evaluate based on classification
predicted_act_df = pd.DataFrame(data=predicted_activity, columns=list(true_act))
predicted_act_label = predicted_act_df.idxmax(axis=1)
true_act_label = true_act.idxmax(axis=1)
predicted_time_label = [0 if a==b else 1 for a, b in zip(true_act_label,predicted_act_label)]

# %%
#plot confusion matrix
LABELS = ['Normal', 'Anomaly']
matrix = confusion_matrix(error_activity_df.ActivityLabel.astype('uint8'), predicted_time_label)
plt.figure(figsize=(7, 7))
sns.heatmap(matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title('Confusion matrix of Activity')
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
score = precision_recall_fscore_support(error_activity_df.ActivityLabel.astype('uint8'), predicted_time_label, average='weighted')
    
print('-------Evaluation of Activity-------')
print('\n')
print('--Weighted Evaluation--')
print('Evaluation')
print('Precision: {:.2f}'.format(score[0]))
print('Recall: {:.2f}'.format(score[1]))
print('Fscore: {:.2f}'.format(score[2]))
print('\n')
score_1 = precision_recall_fscore_support(error_activity_df.ActivityLabel.astype('uint8'), predicted_time_label)
print('--Evaluation for each class--')
print('Normal')
print('Precision: {:.2f}'.format(score_1[0][0]))
print('Recall: {:.2f}'.format(score_1[1][0]))
print('Fscore: {:.2f}'.format(score_1[2][0]))
print('\n')
print('Anomaly')
print('Precision: {:.2f}'.format(score_1[0][1]))
print('Recall: {:.2f}'.format(score_1[1][1]))
print('Fscore: {:.2f}'.format(score_1[2][1]))
# Out:
# -------Evaluation of Activity-------
#
#
# --Weighted Evaluation--
# Evaluation
# Precision: 0.87
# Recall: 0.74
# Fscore: 0.78
#
#
# --Evaluation for each class--
# Normal
# Precision: 0.94
# Recall: 0.75
# Fscore: 0.84
#
#
# Anomaly
# Precision: 0.22
# Recall: 0.61
# Fscore: 0.33

# %%
from sklearn.metrics import accuracy_score
accuracy_score(true_act_label, predicted_act_label)
# Out:
# 0.71392857142857147

# %% [markdown]
# This is the implementation of [**Long Short-Term Memory Encoder-Decoder**](https://arxiv.org/pdf/1406.1078.pdf)

# %%
import importlib
import argparse
import os, sys
import argparse
import pandas as pd
import numpy as np
import pickle
import time

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, roc_curve, auc, precision_recall_curve


# %matplotlib inline

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable
import torch.optim as optim
from torch.nn.utils import clip_grad_norm

# %%
sys.path.insert(0, './../utils/')
from utils import *
from models import *

# %%
#Define parser
name = 'bpi_2012'
#name = 'bpi_2013'
#name = 'small_log'
#name = 'large_log'

parser = {
    'train': True,
    'test': True,
    'model_class': 'LSTMAE',
    'model_name': '',
    'data_dir': '../data/',
    'data_file': name + '.csv',
    'anomaly_pct': 0.1,
    'scaler': 'standardization',
    'input_dir': '../input/{}/'.format(name), 
    'batch_size' : 16,
    'epochs' : 100,
    'no_cuda' : False,
    'seed' : 7,
    'clip': 0.25,
    'layer1': 20,
#    'layer2': 5,
    'lr': 0.001,
    'betas': (0.9, 0.999),   
    'lr_decay': 0.99,
}

args = argparse.Namespace(**parser)
args.output_dir = './output/{0}_{1}_{2}/'.format(name, args.anomaly_pct, args.model_class)

# %%
if not os.path.isdir(args.output_dir):
    os.makedirs(args.output_dir)

# %%
args.cuda = not args.no_cuda and torch.cuda.is_available()
kwargs = {'num_workers': 2, 'pin_memory': True} if args.cuda else {}

# %%
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)

# %%
preprocessed_data_name = os.path.join(args.input_dir, 'preprocessed_data_{}.pkl'.format(args.anomaly_pct))
with open(preprocessed_data_name, 'rb') as f:
    input_train = pickle.load(f)
    input_val = pickle.load(f)
    input_test = pickle.load(f)
    pad_index_train = pickle.load(f)
    pad_index_val = pickle.load(f)
    pad_index_test = pickle.load(f)
    activity_label_test = pickle.load(f)
    time_label_test = pickle.load(f)
    train_case_num = pickle.load(f)
    val_case_num = pickle.load(f)
    test_case_num = pickle.load(f)
    train_row_num = pickle.load(f)
    val_row_num = pickle.load(f)
    test_row_num = pickle.load(f)
    min_value = pickle.load(f)
    max_value = pickle.load(f)
    mean_value = pickle.load(f)
    std_value = pickle.load(f)
    cols = pickle.load(f)
    statistics_storage = pickle.load(f)
    true_time = pickle.load(f)
    true_act = pickle.load(f)
    full_true_time = pickle.load(f)
    full_true_act = pickle.load(f)

# %% [markdown]
# # Load data

# %%
#train
input_trainLoader = torch.utils.data.DataLoader(input_train, batch_size=args.batch_size, shuffle=False, num_workers=2)
pad_index_trainLoader = torch.utils.data.DataLoader(pad_index_train, batch_size=args.batch_size, shuffle=False, num_workers=2)

# %%
#df
normal_df_name = os.path.join(args.input_dir, 'normal_df_{}.csv'.format(args.anomaly_pct))
normal_df = pd.read_csv(normal_df_name)

anomalous_df_name = os.path.join(args.input_dir, 'anomolous_df_{}.csv'.format(args.anomaly_pct))
anomalous_df = pd.read_csv(anomalous_df_name)

#test
caseid_test = normal_df['CaseID'][-test_row_num:]
normal_df_test = normal_df[-test_row_num:]
anomalous_df_test = anomalous_df[-test_row_num:]

# %% [markdown]
# # Build model

# %% [markdown]
# ## Define model

# %%
if args.model_class == 'LSTMAE':
    model = LSTMAE(input_train.shape[2], args.layer1, 1, args.cuda)

if args.cuda:
    model.cuda()

# %%
model.parameters
# Out:
# <bound method Module.parameters of LSTMAE (
#   (encoder): EncoderRNN (
#     (lstm): LSTM(37, 20, batch_first=True)
#   )
#   (decoder): DecoderRNN (
#     (lstm): LSTM(20, 20, batch_first=True)
#     (linear): Linear (20 -> 37)
#   )
# )>

# %% [markdown]
# ## Define loss

# %%
def loss_function(recon_x, x, pad_index):
    MSE = F.mse_loss(recon_x*pad_index, x*pad_index, size_average=False) 
    #BCE = F.binary_cross_entropy(recon_x, x, weight=pad_index, size_average=False)
    return MSE

# %% [markdown]
# ## Define optimizer

# %%
optimizer = optim.Adam(model.parameters(), lr=args.lr, betas=args.betas)

# %%
#Adjust learning rate per epoch: http://pytorch.org/docs/master/optim.html?highlight=adam#torch.optim.Adam

# Method 1:
lambda1 = lambda epoch: args.lr_decay ** epoch
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=[lambda1])

# Method 2:
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=10)

# %%
torch.nn.utils.clip_grad_norm(model.parameters(), args.clip)
# Out:
# 0.0

# %% [markdown]
# # Utils

# %%
def save_model(model, epoch, score):
    model_file = os.path.join(args.output_dir, 'model_{}_epoch{}_score{:.4f}.pth'.format(args.model_class, epoch, score))
    torch.save(model.state_dict(), model_file)

# %%
def load_model(model, model_name):
    model_file = os.path.join(args.output_dir, model_name)
    assert os.path.isfile(model_file), 'Error: no model found!'
    model_state = torch.load(model_file)
    model.load_state_dict(model_state)

# %%
def val(model, input_val, pad_index_val):
    model.eval()
    input_val = Variable(torch.Tensor(input_val).float())
    pad_index_val = Variable(torch.Tensor(pad_index_val).float())
    
    if args.cuda:
        input_val = input_val.cuda()
        pad_index_val = pad_index_val.cuda()
    
    recon_val = model(input_val)    
    loss = loss_function(recon_val, input_val, pad_index_val)
    return loss.data[0]/len(input_test.data)

# %% [markdown]
# # Train

# %%
def train(epoch, model, optimizer):
    model.train()
    train_loss = 0
    for batch_idx, (batch_data, batch_index) in enumerate(zip(input_trainLoader, pad_index_trainLoader)):
        
        batch_data = Variable(batch_data.float())
        batch_index = Variable(batch_index.float())

        if args.cuda:
            batch_data = batch_data.cuda()
            batch_index = batch_index.cuda()
            
        optimizer.zero_grad()
        
        recon_data = model(batch_data)
        
        loss = loss_function(recon_data, batch_data, batch_index)
        
        loss.backward()
        train_loss += loss.data[0]
        optimizer.step()
        
    return train_loss / len(input_trainLoader.dataset)

# %%
if args.train:
    for epoch in range(1, args.epochs + 1):
        init = time.time()
        
        #method 1 scheduler
        scheduler.step()
        
        train_loss = train(epoch, model, optimizer)
        end_train = time.time()
        val_score = val(model, input_val, pad_index_val)
        
        '''
        # To save model
        if epoch == 1:
            current_best = val_score
            save_model(model, epoch, val_score)
        
        else:
            if val_score < current_best:
                current_best = val_score
                save_model(model, epoch, val_score)
        '''
        
        end = time.time()
        print('====> Epoch {} | Train time: {:.4f} ms| End time: {:.4f} ms | Train loss: {:.4f} | Val loss: {:.4f}'.
              format(epoch, (end_train-init)*1000, (end-init)*1000, train_loss, val_score))
else:
    load_model(model, args.model_name)
# Out:
# ====> Epoch 1 | Train time: 8969.8637 ms| End time: 10278.5361 ms | Train loss: 23.3158 | Val loss: 14.0699
# ====> Epoch 2 | Train time: 8901.8354 ms| End time: 10204.5505 ms | Train loss: 10.1385 | Val loss: 8.3406
# ====> Epoch 3 | Train time: 8939.6780 ms| End time: 10248.6017 ms | Train loss: 6.8023 | Val loss: 6.3680
# ====> Epoch 4 | Train time: 8745.1029 ms| End time: 10054.1036 ms | Train loss: 5.4663 | Val loss: 5.3885
# ====> Epoch 5 | Train time: 8610.6124 ms| End time: 9920.5997 ms | Train loss: 4.7806 | Val loss: 4.8099
# ====> Epoch 6 | Train time: 8594.3282 ms| End time: 9899.4210 ms | Train loss: 4.2621 | Val loss: 4.2909
# ====> Epoch 7 | Train time: 8406.9803 ms| End time: 9730.6018 ms | Train loss: 3.9190 | Val loss: 4.0590
# ====> Epoch 8 | Train time: 8336.1835 ms| End time: 9647.0480 ms | Train loss: 3.7839 | Val loss: 3.9660
# ====> Epoch 9 | Train time: 8396.1201 ms| End time: 9698.3943 ms | Train loss: 3.7184 | Val loss: 3.9149
# ====> Epoch 10 | Train time: 8297.5233 ms| End time: 9603.9305 ms | Train loss: 3.6794 | Val loss: 3.8827
# ====> Epoch 11 | Train time: 8395.4639 ms| End time: 9701.6962 ms | Train loss: 3.6551 | Val loss: 3.8623
# ====> Epoch 12 | Train time: 8347.1751 ms| End time: 9662.2953 ms | Train loss: 3.6388 | Val loss: 3.8485
# ====> Epoch 13 | Train time: 8412.3917 ms| End time: 9714.7272 ms | Train loss: 3.6264 | Val loss: 3.8387
# ====> Epoch 14 | Train time: 8301.3198 ms| End time: 9602.5491 ms | Train loss: 3.6177 | Val loss: 3.8306
# ====> Epoch 15 | Train time: 8313.4756 ms| End time: 9615.9730 ms | Train loss: 3.6115 | Val loss: 3.8255
# ====> Epoch 16 | Train time: 8342.0024 ms| End time: 9659.3778 ms | Train loss: 3.6054 | Val loss: 3.8206
# ====> Epoch 17 | Train time: 8352.4396 ms| End time: 9662.6513 ms | Train loss: 3.6013 | Val loss: 3.8168
# ====> Epoch 18 | Train time: 8381.4769 ms| End time: 9687.2778 ms | Train loss: 3.5970 | Val loss: 3.8147
# ====> Epoch 19 | Train time: 8322.9358 ms| End time: 9643.9795 ms | Train loss: 3.5960 | Val loss: 3.8115
# ====> Epoch 20 | Train time: 8362.5355 ms| End time: 9677.9931 ms | Train loss: 3.5911 | Val loss: 3.8098
# ====> Epoch 21 | Train time: 8374.1109 ms| End time: 9679.7667 ms | Train loss: 3.5918 | Val loss: 3.8080
# ====> Epoch 22 | Train time: 8328.3520 ms| End time: 9639.6217 ms | Train loss: 3.5866 | Val loss: 3.8063
# ====> Epoch 23 | Train time: 8340.0636 ms| End time: 9658.6277 ms | Train loss: 3.5876 | Val loss: 3.8069
# ====> Epoch 24 | Train time: 8349.5541 ms| End time: 9664.7272 ms | Train loss: 3.5832 | Val loss: 3.8044
# ====> Epoch 25 | Train time: 8355.1006 ms| End time: 9662.5087 ms | Train loss: 3.5836 | Val loss: 3.8030
# ====> Epoch 26 | Train time: 8330.2276 ms| End time: 9641.8436 ms | Train loss: 3.5799 | Val loss: 3.8004
# ====> Epoch 27 | Train time: 8395.6752 ms| End time: 9698.5171 ms | Train loss: 3.5803 | Val loss: 3.7999
# ====> Epoch 28 | Train time: 8345.9637 ms| End time: 9653.6748 ms | Train loss: 3.5768 | Val loss: 3.7963
# ====> Epoch 29 | Train time: 8350.2245 ms| End time: 9665.5443 ms | Train loss: 3.5765 | Val loss: 3.7955
# ====> Epoch 30 | Train time: 8381.6090 ms| End time: 9688.9169 ms | Train loss: 3.5752 | Val loss: 3.7945
# ====> Epoch 31 | Train time: 8351.9812 ms| End time: 9657.2945 ms | Train loss: 3.5724 | Val loss: 3.7905
# ====> Epoch 32 | Train time: 8365.8082 ms| End time: 9678.9911 ms | Train loss: 3.5707 | Val loss: 3.7885
# ====> Epoch 33 | Train time: 8266.1560 ms| End time: 9572.9373 ms | Train loss: 3.5746 | Val loss: 3.7883
# ====> Epoch 34 | Train time: 8408.0164 ms| End time: 9726.9948 ms | Train loss: 3.5659 | Val loss: 3.7857
# ====> Epoch 35 | Train time: 8417.0513 ms| End time: 9729.3010 ms | Train loss: 3.5663 | Val loss: 3.7841
# ====> Epoch 36 | Train time: 8381.6390 ms| End time: 9686.6219 ms | Train loss: 3.5640 | Val loss: 3.7876
# ====> Epoch 37 | Train time: 8399.3454 ms| End time: 9708.4277 ms | Train loss: 3.5667 | Val loss: 3.7814
# ====> Epoch 38 | Train time: 8354.4848 ms| End time: 9668.8454 ms | Train loss: 3.5623 | Val loss: 3.7804
# ====> Epoch 39 | Train time: 8420.1930 ms| End time: 9731.8251 ms | Train loss: 3.5679 | Val loss: 3.7800
# ====> Epoch 40 | Train time: 8382.1852 ms| End time: 9684.4282 ms | Train loss: 3.5595 | Val loss: 3.7779
# ====> Epoch 41 | Train time: 8392.4050 ms| End time: 9702.0266 ms | Train loss: 3.5589 | Val loss: 3.7771
# ====> Epoch 42 | Train time: 8386.2886 ms| End time: 9696.4858 ms | Train loss: 3.5589 | Val loss: 3.7803
# ====> Epoch 43 | Train time: 8424.1276 ms| End time: 9739.5687 ms | Train loss: 3.5610 | Val loss: 3.7751
# ====> Epoch 44 | Train time: 8405.7190 ms| End time: 9718.3845 ms | Train loss: 3.5593 | Val loss: 3.7742
# ====> Epoch 45 | Train time: 8390.8429 ms| End time: 9711.8235 ms | Train loss: 3.5562 | Val loss: 3.7736
# ====> Epoch 46 | Train time: 8413.2636 ms| End time: 9730.0224 ms | Train loss: 3.5562 | Val loss: 3.7754
# ====> Epoch 47 | Train time: 8408.0157 ms| End time: 9717.5055 ms | Train loss: 3.5596 | Val loss: 3.7723
# ====> Epoch 48 | Train time: 8413.9235 ms| End time: 9729.3270 ms | Train loss: 3.5562 | Val loss: 3.7716
# ====> Epoch 49 | Train time: 8403.3427 ms| End time: 9706.0444 ms | Train loss: 3.5604 | Val loss: 3.7715
# ====> Epoch 50 | Train time: 8406.9941 ms| End time: 9727.5379 ms | Train loss: 3.5535 | Val loss: 3.7706
# ====> Epoch 51 | Train time: 8399.4617 ms| End time: 9714.8752 ms | Train loss: 3.5534 | Val loss: 3.7706
# ====> Epoch 52 | Train time: 8312.3314 ms| End time: 9633.0090 ms | Train loss: 3.5544 | Val loss: 3.7701
# ====> Epoch 53 | Train time: 8347.6181 ms| End time: 9660.2924 ms | Train loss: 3.5539 | Val loss: 3.7693
# ====> Epoch 54 | Train time: 8361.4929 ms| End time: 9671.3405 ms | Train loss: 3.5529 | Val loss: 3.7711
# ====> Epoch 55 | Train time: 8237.4413 ms| End time: 9557.3335 ms | Train loss: 3.5555 | Val loss: 3.7685
# ====> Epoch 56 | Train time: 8205.4217 ms| End time: 9523.2935 ms | Train loss: 3.5525 | Val loss: 3.7683
# ====> Epoch 57 | Train time: 8164.5634 ms| End time: 9480.4025 ms | Train loss: 3.5533 | Val loss: 3.7679
# ====> Epoch 58 | Train time: 8192.9352 ms| End time: 9505.1312 ms | Train loss: 3.5515 | Val loss: 3.7677
# ====> Epoch 59 | Train time: 8207.1891 ms| End time: 9523.9611 ms | Train loss: 3.5517 | Val loss: 3.7675
# ====> Epoch 60 | Train time: 8254.9617 ms| End time: 9557.1818 ms | Train loss: 3.5534 | Val loss: 3.7671
# ====> Epoch 61 | Train time: 8240.2096 ms| End time: 9554.4727 ms | Train loss: 3.5522 | Val loss: 3.7668
# ====> Epoch 62 | Train time: 8228.0729 ms| End time: 9534.6494 ms | Train loss: 3.5505 | Val loss: 3.7669
# ====> Epoch 63 | Train time: 8313.7419 ms| End time: 9623.1925 ms | Train loss: 3.5512 | Val loss: 3.7664
# ====> Epoch 64 | Train time: 8274.0149 ms| End time: 9588.0215 ms | Train loss: 3.5503 | Val loss: 3.7667
# ====> Epoch 65 | Train time: 8245.3120 ms| End time: 9556.4084 ms | Train loss: 3.5519 | Val loss: 3.7660
# ====> Epoch 66 | Train time: 8250.8047 ms| End time: 9566.6144 ms | Train loss: 3.5514 | Val loss: 3.7658
# ====> Epoch 67 | Train time: 8255.1434 ms| End time: 9565.7394 ms | Train loss: 3.5496 | Val loss: 3.7661
# ====> Epoch 68 | Train time: 8227.3748 ms| End time: 9539.6380 ms | Train loss: 3.5499 | Val loss: 3.7661
# ====> Epoch 69 | Train time: 8225.4052 ms| End time: 9531.3303 ms | Train loss: 3.5508 | Val loss: 3.7654
# ====> Epoch 70 | Train time: 8252.2848 ms| End time: 9555.8405 ms | Train loss: 3.5505 | Val loss: 3.7652
# ====> Epoch 71 | Train time: 8247.3431 ms| End time: 9563.7336 ms | Train loss: 3.5492 | Val loss: 3.7655
# ====> Epoch 72 | Train time: 8258.2648 ms| End time: 9570.5061 ms | Train loss: 3.5496 | Val loss: 3.7651
# ====> Epoch 73 | Train time: 8255.7843 ms| End time: 9572.1729 ms | Train loss: 3.5489 | Val loss: 3.7649
# ====> Epoch 74 | Train time: 8237.8676 ms| End time: 9546.6440 ms | Train loss: 3.5498 | Val loss: 3.7653
# ====> Epoch 75 | Train time: 8227.1414 ms| End time: 9542.5239 ms | Train loss: 3.5490 | Val loss: 3.7647
# ====> Epoch 76 | Train time: 8241.8535 ms| End time: 9577.7273 ms | Train loss: 3.5489 | Val loss: 3.7645
# ====> Epoch 77 | Train time: 8260.5255 ms| End time: 9571.8524 ms | Train loss: 3.5492 | Val loss: 3.7644
# ====> Epoch 78 | Train time: 8250.3817 ms| End time: 9563.5300 ms | Train loss: 3.5486 | Val loss: 3.7644
# ====> Epoch 79 | Train time: 8242.4207 ms| End time: 9568.8055 ms | Train loss: 3.5490 | Val loss: 3.7643
# ====> Epoch 80 | Train time: 8232.7430 ms| End time: 9545.4438 ms | Train loss: 3.5485 | Val loss: 3.7644
# ====> Epoch 81 | Train time: 8253.7100 ms| End time: 9570.4749 ms | Train loss: 3.5482 | Val loss: 3.7645
# ====> Epoch 82 | Train time: 8235.6060 ms| End time: 9549.2578 ms | Train loss: 3.5491 | Val loss: 3.7641
# ====> Epoch 83 | Train time: 8235.6825 ms| End time: 9546.9029 ms | Train loss: 3.5487 | Val loss: 3.7640
# ====> Epoch 84 | Train time: 8267.2417 ms| End time: 9586.9334 ms | Train loss: 3.5478 | Val loss: 3.7644
# ====> Epoch 85 | Train time: 8236.5046 ms| End time: 9546.7439 ms | Train loss: 3.5480 | Val loss: 3.7640
# ====> Epoch 86 | Train time: 8253.2475 ms| End time: 9559.2039 ms | Train loss: 3.5476 | Val loss: 3.7638
# ====> Epoch 87 | Train time: 8253.6013 ms| End time: 9561.1215 ms | Train loss: 3.5482 | Val loss: 3.7644
# ====> Epoch 88 | Train time: 8261.0087 ms| End time: 9568.1307 ms | Train loss: 3.5476 | Val loss: 3.7637
# ====> Epoch 89 | Train time: 8216.7013 ms| End time: 9531.7616 ms | Train loss: 3.5474 | Val loss: 3.7637
# ====> Epoch 90 | Train time: 8247.5653 ms| End time: 9549.9940 ms | Train loss: 3.5481 | Val loss: 3.7636
# ====> Epoch 91 | Train time: 8238.6441 ms| End time: 9552.8069 ms | Train loss: 3.5475 | Val loss: 3.7640
# ====> Epoch 92 | Train time: 8255.1124 ms| End time: 9561.1994 ms | Train loss: 3.5471 | Val loss: 3.7635
# ====> Epoch 93 | Train time: 8239.9616 ms| End time: 9556.0977 ms | Train loss: 3.5477 | Val loss: 3.7640
# ====> Epoch 94 | Train time: 8272.6688 ms| End time: 9578.1980 ms | Train loss: 3.5471 | Val loss: 3.7634
# ====> Epoch 95 | Train time: 8264.6086 ms| End time: 9584.4858 ms | Train loss: 3.5474 | Val loss: 3.7636
# ====> Epoch 96 | Train time: 8249.3143 ms| End time: 9560.7743 ms | Train loss: 3.5472 | Val loss: 3.7633
# ====> Epoch 97 | Train time: 8258.1949 ms| End time: 9562.8583 ms | Train loss: 3.5470 | Val loss: 3.7635
# ====> Epoch 98 | Train time: 8261.4794 ms| End time: 9590.3492 ms | Train loss: 3.5469 | Val loss: 3.7633
# ====> Epoch 99 | Train time: 8235.4672 ms| End time: 9551.9593 ms | Train loss: 3.5469 | Val loss: 3.7634
# ====> Epoch 100 | Train time: 8281.2829 ms| End time: 9587.9912 ms | Train loss: 3.5470 | Val loss: 3.7634

# %% [markdown]
# # Predict

# %%
if args.test:
    input_test = Variable(torch.Tensor(input_test).float())
    if args.cuda:
        input_test = input_test.cuda()
    
    print('Predicting...')
    recon_test = model(input_test)
    
    print('Separating prediction ...')
    predicted_time, predicted_activity = getPrediction(recon_test, pad_index_test)
    
    print('Done!')
# Out:
# Predicting...
# Separating prediction ...
# Done!

# %% [markdown]
# # Evaluate

# %% [markdown]
# ## Time

# %%
#Fix predicted time
time_df = pd.DataFrame({'CaseID': caseid_test,
                        'PredictedTime': predicted_time})

groupByCase = time_df.groupby(['CaseID'])
fixed_time_df = pd.DataFrame(columns=list(time_df))

for case, group in groupByCase:
    group.iloc[0, 1] = -mean_value/std_value
    fixed_time_df = fixed_time_df.append(group)
# Out:
# /home/pllab/miniconda2/envs/pydata/lib/python3.5/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
fixed_predicted_time = fixed_time_df['PredictedTime']

# %%
error = np.abs(true_time - fixed_predicted_time)
error_time_df = pd.DataFrame({'Error': error,
                              'TimeLabel': time_label_test})

# %%
precision, recall, th = precision_recall_curve(error_time_df.TimeLabel, error_time_df.Error, pos_label=1)
plt.figure(figsize=(20, 5))
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
time_threshold = np.mean(error_time_df['Error'])
print('Threshold of Time: {}'.format(time_threshold))
# Out:
# Threshold of Time: 0.00544223743895561

# %%
plotOverlapReconstructionError(error_time_df, variable='Time', output_dir=args.output_dir, save=True)

# %%
plotReconstructionError(error_time_df, variable='Time')

# %%
plotConfusionMaxtrix(error_time_df, threshold=time_threshold, variable='Time', output_dir=args.output_dir, save=True)

# %%
evalScore(error_time_df, threshold=time_threshold, variable='Time')
# Out:
# -------Evaluation of Time-------
#
#
# --Weighted Evaluation--
# Evaluation of Time
# Precision: 0.84
# Recall: 0.65
# Fscore: 0.72
#
#
# --Evaluation for each class--
# Normal
# Precision: 0.92
# Recall: 0.67
# Fscore: 0.78
#
#
# Anomaly
# Precision: 0.12
# Recall: 0.42
# Fscore: 0.18

# %%
fpr, tpr, thresholds = roc_curve(error_time_df.TimeLabel, error_time_df.Error, pos_label=1)
roc_auc = auc(fpr, tpr)

#plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig(args.output_dir + 'ROC_time.png')
plt.show();

# %%
#get submission
if args.scaler == 'standardization':
    inverse_scaled_time = [x*std_value+mean_value for x in fixed_predicted_time]
else:
    inverse_scaled_time = [x*(max_value-min_value)+min_value for x in fixed_predicted_time]
    
predicted_time_label_test = [1 if e > time_threshold else 0 for e in error_time_df.Error.values]

submission_time = pd.DataFrame({'AnomalousDuration': anomalous_df_test['AnomalousDuration'].copy(),
                                'Activity': normal_df_test['Activity'].copy(),
                                'AnomalousCumDuration': anomalous_df_test['AnomalousCumDuration'].copy(),
                                'PredictedCumDuration': inverse_scaled_time,
                                'TimeLabel': time_label_test,
                                'PredictedTimeLabel': predicted_time_label_test})

# %%
submission_time.head()
# Out:
#                           Activity  AnomalousCumDuration  AnomalousDuration  \
# 214377        A_SUBMITTED-COMPLETE                 0.000              0.000
# 214378  A_PARTLYSUBMITTED-COMPLETE                 0.276              0.276
# 214379         A_DECLINED-COMPLETE                31.917             31.641
# 214380        A_SUBMITTED-COMPLETE                 0.000              0.000
# 214381  A_PARTLYSUBMITTED-COMPLETE                 0.555              0.555
#
#         PredictedCumDuration  PredictedTimeLabel TimeLabel
# 214377              0.000000                   0         0
# 214378             20.182445                   0         0
# 214379           1742.664295                   0         0
# 214380              0.000000                   0         0
# 214381             20.474203                   0         0

# %%
groupByActivity = submission_time.groupby(['Activity'])

for act, group in groupByActivity:
    plotDurationofPredictedTimeLabel(act, group, statistics_storage, args.output_dir, True)

# %%
submission_time.head()
# Out:
#                           Activity  AnomalousCumDuration  AnomalousDuration  \
# 214377        A_SUBMITTED-COMPLETE                 0.000              0.000
# 214378  A_PARTLYSUBMITTED-COMPLETE                 0.276              0.276
# 214379         A_DECLINED-COMPLETE                31.917             31.641
# 214380        A_SUBMITTED-COMPLETE                 0.000              0.000
# 214381  A_PARTLYSUBMITTED-COMPLETE                 0.555              0.555
#
#         PredictedCumDuration  PredictedTimeLabel TimeLabel
# 214377              0.000000                   0         0
# 214378             20.182445                   0         0
# 214379           1742.664295                   0         0
# 214380              0.000000                   0         0
# 214381             20.474203                   0         0

# %%
act_list = [i for i in submission_time['Activity'].unique()]
false_positive_df = submission_time[(submission_time['PredictedTimeLabel']== 1)&(submission_time['TimeLabel']== 0)]
false_negative_df = submission_time[(submission_time['PredictedTimeLabel']== 0)&(submission_time['TimeLabel']== 1)]

for act in act_list:
    plotFalseDuration(false_positive_df, false_negative_df, act, statistics_storage)

# %% [markdown]
# ## Activity

# %% [markdown]
# ### Threshold

# %%
# error = np.mean(np.power(true_act - predicted_activity, 2), axis = 1)
error = np.mean(np.abs(true_act - predicted_activity), axis = 1)
error_activity_df = pd.DataFrame({'Error': error,
                                  'ActivityLabel': activity_label_test})

# %%
error_activity_df.head()
# Out:
#         ActivityLabel     Error
# 214377              0  0.051562
# 214378              0  0.051560
# 214379              0  0.051574
# 214380              0  0.051562
# 214381              0  0.051560

# %%
precision, recall, th = precision_recall_curve(error_activity_df.ActivityLabel, error_activity_df.Error, pos_label=1)
plt.figure(figsize=(20, 5))
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
activity_threshold = np.mean(error_activity_df['Error'])
print('Threshold of Activity: {}'.format(activity_threshold))
# Out:
# Threshold of Activity: 0.05200909757510927

# %%
plotConfusionMaxtrix(error_activity_df, activity_threshold, variable='Activity', output_dir=args.output_dir, save=True)

# %%
plotOverlapReconstructionError(error_activity_df, variable='Activity', output_dir=args.output_dir, save=True)

# %%
plotReconstructionError(error_activity_df)

# %%
evalScore(error_activity_df, activity_threshold, variable='Activity')
# Out:
# -------Evaluation of Activity-------
#
#
# --Weighted Evaluation--
# Evaluation of Activity
# Precision: 0.87
# Recall: 0.80
# Fscore: 0.83
#
#
# --Evaluation for each class--
# Normal
# Precision: 0.93
# Recall: 0.84
# Fscore: 0.89
#
#
# Anomaly
# Precision: 0.26
# Recall: 0.49
# Fscore: 0.34

# %%
fpr, tpr, thresholds = roc_curve(error_activity_df.ActivityLabel, error_activity_df.Error, pos_label=1)
roc_auc = auc(fpr, tpr)

#plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig(args.output_dir+'ROC_Act.png')
plt.show();

# %% [markdown]
# ### Argmax

# %%
# evaluate based on classification
predicted_act_df = pd.DataFrame(data=predicted_activity, columns=list(true_act))
predicted_act_label = predicted_act_df.idxmax(axis=1)
true_act_label = true_act.idxmax(axis=1)
predicted_time_label = [0 if a==b else 1 for a, b in zip(true_act_label,predicted_act_label)]

# %%
#plot confusion matrix
LABELS = ['Normal', 'Anomaly']
matrix = confusion_matrix(error_activity_df.ActivityLabel.astype('uint8'), predicted_time_label)
plt.figure(figsize=(7, 7))
sns.heatmap(matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title('Confusion matrix of Activity')
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
score = precision_recall_fscore_support(error_activity_df.ActivityLabel.astype('uint8'), predicted_time_label, average='weighted')
    
print('-------Evaluation of Activity-------')
print('\n')
print('--Weighted Evaluation--')
print('Evaluation')
print('Precision: {:.2f}'.format(score[0]))
print('Recall: {:.2f}'.format(score[1]))
print('Fscore: {:.2f}'.format(score[2]))
print('\n')
score_1 = precision_recall_fscore_support(error_activity_df.ActivityLabel.astype('uint8'), predicted_time_label)
print('--Evaluation for each class--')
print('Normal')
print('Precision: {:.2f}'.format(score_1[0][0]))
print('Recall: {:.2f}'.format(score_1[1][0]))
print('Fscore: {:.2f}'.format(score_1[2][0]))
print('\n')
print('Anomaly')
print('Precision: {:.2f}'.format(score_1[0][1]))
print('Recall: {:.2f}'.format(score_1[1][1]))
print('Fscore: {:.2f}'.format(score_1[2][1]))
# Out:
# -------Evaluation of Activity-------
#
#
# --Weighted Evaluation--
# Evaluation
# Precision: 0.87
# Recall: 0.83
# Fscore: 0.84
#
#
# --Evaluation for each class--
# Normal
# Precision: 0.93
# Recall: 0.87
# Fscore: 0.90
#
#
# Anomaly
# Precision: 0.29
# Recall: 0.45
# Fscore: 0.35

# %%
from sklearn.metrics import accuracy_score
accuracy_score(true_act_label, predicted_act_label)
# Out:
# 0.83811136900654493

# %% [markdown]
# This is the implementation of [**Variational Autoencoder**](https://arxiv.org/pdf/1312.6114.pdf)

# %%
import importlib
import argparse
import os, sys
import argparse
import pandas as pd
import numpy as np
import pickle
import time

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, roc_curve, auc, precision_recall_curve

# %matplotlib inline

# %%
import torch
import torch.utils.data
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import torch.optim.lr_scheduler
from torch.autograd import Variable
from torchvision import transforms

# %%
sys.path.insert(0, './../utils/')
from utils import *
from models import *

# %%
#Define parser
#name = 'bpi_2012'
#name = 'bpi_2013'
#name = 'small_log'
name = 'large_log'

parser = {
    'train': True,
    'test': True,
    'model_class': 'VAE_dropout', #VAE
    'model_name': '',
    'data_dir': '../data/',
    'data_file': name + '.csv',
    'anomaly_pct': 0.1,
    'scaler': 'standardization',
    'input_dir': '../input/{}/'.format(name), 
    'batch_size' : 16,
    'epochs' : 100,
    'no_cuda' : False,
    'seed' : 7,
    'layer1': 50,
    'layer2': 20,
    'lr': 0.001,
    'betas': (0.9, 0.999),   
    'lr_decay': 0.99,
}

args = argparse.Namespace(**parser)
args.output_dir = './output/{0}_{1}_{2}/'.format(name, args.anomaly_pct, args.model_class)

# %%
if not os.path.isdir(args.output_dir):
    os.makedirs(args.output_dir)

# %%
args.cuda = not args.no_cuda and torch.cuda.is_available()
kwargs = {'num_workers': 2, 'pin_memory': True} if args.cuda else {}

# %%
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)

# %%
preprocessed_data_name = os.path.join(args.input_dir, 'preprocessed_data_{}.pkl'.format(args.anomaly_pct))
with open(preprocessed_data_name, 'rb') as f:
    input_train = pickle.load(f)
    input_val = pickle.load(f)
    input_test = pickle.load(f)
    pad_index_train = pickle.load(f)
    pad_index_val = pickle.load(f)
    pad_index_test = pickle.load(f)
    activity_label_test = pickle.load(f)
    time_label_test = pickle.load(f)
    train_case_num = pickle.load(f)
    val_case_num = pickle.load(f)
    test_case_num = pickle.load(f)
    train_row_num = pickle.load(f)
    val_row_num = pickle.load(f)
    test_row_num = pickle.load(f)
    min_value = pickle.load(f)
    max_value = pickle.load(f)
    mean_value = pickle.load(f)
    std_value = pickle.load(f)
    cols = pickle.load(f)
    statistics_storage = pickle.load(f)
    true_time = pickle.load(f)
    true_act = pickle.load(f)
    full_true_time = pickle.load(f)
    full_true_act = pickle.load(f)

# %% [markdown]
# # Load data

# %%
#train
input_trainLoader = torch.utils.data.DataLoader(input_train, batch_size=args.batch_size, shuffle=False, num_workers=2)
pad_index_trainLoader = torch.utils.data.DataLoader(pad_index_train, batch_size=args.batch_size, shuffle=False, num_workers=2)

# %%
#df
normal_df_name = os.path.join(args.input_dir, 'normal_df_{}.csv'.format(args.anomaly_pct))
normal_df = pd.read_csv(normal_df_name)

anomalous_df_name = os.path.join(args.input_dir, 'anomolous_df_{}.csv'.format(args.anomaly_pct))
anomalous_df = pd.read_csv(anomalous_df_name)

#test
caseid_test = normal_df['CaseID'][-test_row_num:]
normal_df_test = normal_df[-test_row_num:]
anomalous_df_test = anomalous_df[-test_row_num:]

# %%
normal_df.head()
# Out:
#    CaseID    Activity    CompleteTimestamp  Duration  CumDuration
# 0       1  Activity A  1970-01-01 09:00:00       0.0          0.0
# 1       1  Activity D  1970-01-01 10:00:00    3600.0       3600.0
# 2       1  Activity C  1970-01-01 10:00:00       0.0       3600.0
# 3       1  Activity B  1970-01-01 11:00:00    3600.0       7200.0
# 4       1  Activity E  1970-01-01 12:00:00    3600.0      10800.0

# %%
anomalous_df.head()
# Out:
#    CaseID AnomalousActivity  AnomalousCompleteTimestamp  AnomalousDuration  \
# 0       1        Activity A  1970-01-01 09:00:00.000000           0.000000
# 1       1        Activity D  1970-01-01 10:00:00.000000        3600.000000
# 2       1        Activity C  1970-01-01 10:00:00.000000           0.000000
# 3       1        Activity B  1970-01-01 11:00:00.000000        3600.000000
# 4       1        Activity E  1970-01-01 12:54:15.026986        6855.026986
#
#    AnomalousCumDuration  ActivityLabel  TimeLabel
# 0              0.000000              0          0
# 1           3600.000000              0          0
# 2           3600.000000              0          0
# 3           7200.000000              0          0
# 4          14055.026986              0          1

# %% [markdown]
# # Build model

# %% [markdown]
# ## Define model

# %%
if args.model_class == 'VAE':
    model = VAE(input_train.shape, args.layer1, args.layer2, True)

if args.model_class == 'VAE_dropout':
    model = VAE_dropout(input_train.shape, args.layer1, args.layer2, True)

if args.cuda:
    model.cuda()

# %%
model
# Out:
# VAE_dropout (
#   (fc1): Linear (88 -> 50)
#   (fc21): Linear (50 -> 20)
#   (fc22): Linear (50 -> 20)
#   (fc3): Linear (20 -> 50)
#   (fc4): Linear (50 -> 88)
#   (relu): ReLU ()
#   (dout): Dropout (p = 0.2)
# )

# %% [markdown]
# ## Define loss

# %%
def loss_function(recon_x, x, mu, logvar, avai_mask): 
    MSE = F.mse_loss(recon_x*avai_mask, x*avai_mask, size_average=False)
    KLD_element = mu.pow(2).add_(logvar.exp()).mul_(-1).add_(1).add_(logvar)
    KLD = torch.sum(KLD_element).mul_(-0.5)
    loss = MSE+KLD
    return loss

# %% [markdown]
# ## Define optimizer

# %%
optimizer = optim.Adam(model.parameters(), lr=args.lr, betas=args.betas)

# %%
#Adjust learning rate per epoch: http://pytorch.org/docs/master/optim.html?highlight=adam#how-to-adjust-learning-rate

# Method 1:

#lambda1 = lambda epoch: epoch // args.lr_step
lambda1 = lambda epoch: args.lr_decay ** epoch
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=[lambda1])

# Method 2:
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=10)

# %% [markdown]
# # Utils

# %%
def save_model(model, epoch, score):
    model_file = os.path.join(args.output_dir, 'model_{}_epoch{}_score{:.4f}.pth'.format(args.model_class, epoch, score))
    torch.save(model.state_dict(), model_file)

# %%
def load_model(model, model_name):
    model_file = os.path.join(args.output_dir, model_name)
    assert os.path.isfile(model_file), 'Error: no model found!'
    model_state = torch.load(model_file)
    model.load_state_dict(model_state)

# %%
def val(model, input_val, pad_index_val):
    model.eval()
    input_val = Variable(torch.Tensor(input_val).float())
    pad_index_val = Variable(torch.Tensor(pad_index_val).float())
    
    if args.cuda:
        input_val = input_val.cuda()
        pad_index_val = pad_index_val.cuda()
    
    recon_val, mu, logvar = model(input_val)  
    loss = loss_function(recon_val, input_val, mu, logvar, pad_index_val)
    return loss.data[0]/len(input_test.data)

# %% [markdown]
# # Train

# %%
def train(epoch, model, optimizer):
    model.train()
    train_loss = 0
    for batch_idx, (batch_data, batch_index) in enumerate(zip(input_trainLoader, pad_index_trainLoader)):
        
        batch_data = Variable(batch_data.float())
        batch_index = Variable(batch_index.float())

        if args.cuda:
            batch_data = batch_data.cuda()
            batch_index = batch_index.cuda()
            
        optimizer.zero_grad()
        
        recon_data, mu, logvar = model(batch_data)
        
        loss = loss_function(recon_data, batch_data, mu, logvar, batch_index)
        
        loss.backward()
        train_loss += loss.data[0]
        optimizer.step()
        
    return train_loss / len(input_trainLoader.dataset)

# %%
if args.train:
    for epoch in range(1, args.epochs + 1):
        init = time.time()
        
        #method 1 scheduler
        scheduler.step()
        
        train_loss = train(epoch, model, optimizer)
        end_train = time.time()
        val_score = val(model, input_val, pad_index_val)
        
        '''
        # To save model
        if epoch == 1:
            current_best = val_score
            save_model(model, epoch, val_score)
        
        else:
            if val_score < current_best:
                current_best = val_score
                save_model(model, epoch, val_score)
        '''
        
        end = time.time()
        print('====> Epoch {} | Train time: {:.4f} ms| End time: {:.4f} ms | Train loss: {:.4f} | Val loss: {:.4f}'.
              format(epoch, (end_train-init)*1000, (end-init)*1000, train_loss, val_score))
else:
    load_model(model, args.model_name)
# Out:
# ====> Epoch 1 | Train time: 1772.2144 ms| End time: 1800.1423 ms | Train loss: 33.7991 | Val loss: 8.0149
# ====> Epoch 2 | Train time: 1626.6227 ms| End time: 1652.6322 ms | Train loss: 8.3001 | Val loss: 4.6308
# ====> Epoch 3 | Train time: 1601.8155 ms| End time: 1627.4686 ms | Train loss: 5.0357 | Val loss: 3.5967
# ====> Epoch 4 | Train time: 1648.2525 ms| End time: 1677.8324 ms | Train loss: 3.8097 | Val loss: 3.1948
# ====> Epoch 5 | Train time: 1613.9805 ms| End time: 1643.3344 ms | Train loss: 3.3228 | Val loss: 3.0308
# ====> Epoch 6 | Train time: 1640.2388 ms| End time: 1669.9827 ms | Train loss: 3.1109 | Val loss: 2.9708
# ====> Epoch 7 | Train time: 1695.1265 ms| End time: 1720.6895 ms | Train loss: 3.0108 | Val loss: 2.9439
# ====> Epoch 8 | Train time: 1679.4145 ms| End time: 1705.2939 ms | Train loss: 2.9709 | Val loss: 2.9399
# ====> Epoch 9 | Train time: 1678.2300 ms| End time: 1703.7983 ms | Train loss: 2.9483 | Val loss: 2.9332
# ====> Epoch 10 | Train time: 1658.4303 ms| End time: 1688.1163 ms | Train loss: 2.9371 | Val loss: 2.9344
# ====> Epoch 11 | Train time: 1665.4737 ms| End time: 1694.9210 ms | Train loss: 2.9311 | Val loss: 2.9348
# ====> Epoch 12 | Train time: 1679.3334 ms| End time: 1705.1449 ms | Train loss: 2.9264 | Val loss: 2.9335
# ====> Epoch 13 | Train time: 1650.8582 ms| End time: 1680.3858 ms | Train loss: 2.9255 | Val loss: 2.9308
# ====> Epoch 14 | Train time: 1665.6976 ms| End time: 1691.4914 ms | Train loss: 2.9230 | Val loss: 2.9310
# ====> Epoch 15 | Train time: 1628.6092 ms| End time: 1658.1912 ms | Train loss: 2.9213 | Val loss: 2.9293
# ====> Epoch 16 | Train time: 1680.8045 ms| End time: 1710.2828 ms | Train loss: 2.9196 | Val loss: 2.9295
# ====> Epoch 17 | Train time: 1646.4520 ms| End time: 1676.0230 ms | Train loss: 2.9183 | Val loss: 2.9293
# ====> Epoch 18 | Train time: 1676.0509 ms| End time: 1701.7744 ms | Train loss: 2.9177 | Val loss: 2.9286
# ====> Epoch 19 | Train time: 1649.5504 ms| End time: 1678.8142 ms | Train loss: 2.9169 | Val loss: 2.9284
# ====> Epoch 20 | Train time: 1663.2504 ms| End time: 1692.9646 ms | Train loss: 2.9166 | Val loss: 2.9283
# ====> Epoch 21 | Train time: 1662.7085 ms| End time: 1688.5920 ms | Train loss: 2.9163 | Val loss: 2.9285
# ====> Epoch 22 | Train time: 1660.6889 ms| End time: 1690.3000 ms | Train loss: 2.9161 | Val loss: 2.9285
# ====> Epoch 23 | Train time: 1707.0298 ms| End time: 1736.3906 ms | Train loss: 2.9161 | Val loss: 2.9285
# ====> Epoch 24 | Train time: 1671.6230 ms| End time: 1701.2277 ms | Train loss: 2.9162 | Val loss: 2.9285
# ====> Epoch 25 | Train time: 1679.7121 ms| End time: 1705.7440 ms | Train loss: 2.9161 | Val loss: 2.9284
# ====> Epoch 26 | Train time: 1608.8758 ms| End time: 1634.6362 ms | Train loss: 2.9160 | Val loss: 2.9283
# ====> Epoch 27 | Train time: 1636.4551 ms| End time: 1666.2338 ms | Train loss: 2.9159 | Val loss: 2.9284
# ====> Epoch 28 | Train time: 1663.4450 ms| End time: 1688.9369 ms | Train loss: 2.9158 | Val loss: 2.9284
# ====> Epoch 29 | Train time: 1677.7582 ms| End time: 1703.7356 ms | Train loss: 2.9159 | Val loss: 2.9284
# ====> Epoch 30 | Train time: 1626.0915 ms| End time: 1655.7469 ms | Train loss: 2.9158 | Val loss: 2.9284
# ====> Epoch 31 | Train time: 1679.1501 ms| End time: 1708.5893 ms | Train loss: 2.9158 | Val loss: 2.9288
# ====> Epoch 32 | Train time: 1658.7882 ms| End time: 1689.1384 ms | Train loss: 2.9161 | Val loss: 2.9284
# ====> Epoch 33 | Train time: 1664.9485 ms| End time: 1694.6118 ms | Train loss: 2.9158 | Val loss: 2.9284
# ====> Epoch 34 | Train time: 1668.2408 ms| End time: 1697.8741 ms | Train loss: 2.9156 | Val loss: 2.9282
# ====> Epoch 35 | Train time: 1705.4060 ms| End time: 1731.2980 ms | Train loss: 2.9162 | Val loss: 2.9285
# ====> Epoch 36 | Train time: 1679.5866 ms| End time: 1709.3270 ms | Train loss: 2.9160 | Val loss: 2.9285
# ====> Epoch 37 | Train time: 1682.4777 ms| End time: 1712.2378 ms | Train loss: 2.9157 | Val loss: 2.9284
# ====> Epoch 38 | Train time: 1680.2506 ms| End time: 1706.0862 ms | Train loss: 2.9158 | Val loss: 2.9283
# ====> Epoch 39 | Train time: 1680.0096 ms| End time: 1705.8630 ms | Train loss: 2.9155 | Val loss: 2.9281
# ====> Epoch 40 | Train time: 1680.1889 ms| End time: 1709.7075 ms | Train loss: 2.9156 | Val loss: 2.9283
# ====> Epoch 41 | Train time: 1648.0927 ms| End time: 1674.1586 ms | Train loss: 2.9156 | Val loss: 2.9283
# ====> Epoch 42 | Train time: 1661.9787 ms| End time: 1687.7267 ms | Train loss: 2.9157 | Val loss: 2.9283
# ====> Epoch 43 | Train time: 1610.4424 ms| End time: 1640.0232 ms | Train loss: 2.9155 | Val loss: 2.9283
# ====> Epoch 44 | Train time: 1684.5882 ms| End time: 1710.0987 ms | Train loss: 2.9155 | Val loss: 2.9283
# ====> Epoch 45 | Train time: 1691.2832 ms| End time: 1717.3154 ms | Train loss: 2.9156 | Val loss: 2.9282
# ====> Epoch 46 | Train time: 1658.2677 ms| End time: 1687.7508 ms | Train loss: 2.9154 | Val loss: 2.9283
# ====> Epoch 47 | Train time: 1674.9477 ms| End time: 1704.5879 ms | Train loss: 2.9156 | Val loss: 2.9282
# ====> Epoch 48 | Train time: 1656.3931 ms| End time: 1686.0569 ms | Train loss: 2.9155 | Val loss: 2.9282
# ====> Epoch 49 | Train time: 1680.1887 ms| End time: 1705.8563 ms | Train loss: 2.9155 | Val loss: 2.9282
# ====> Epoch 50 | Train time: 1640.6450 ms| End time: 1670.5022 ms | Train loss: 2.9155 | Val loss: 2.9282
# ====> Epoch 51 | Train time: 1671.4718 ms| End time: 1701.5357 ms | Train loss: 2.9154 | Val loss: 2.9282
# ====> Epoch 52 | Train time: 1659.6525 ms| End time: 1685.9276 ms | Train loss: 2.9155 | Val loss: 2.9283
# ====> Epoch 53 | Train time: 1665.9269 ms| End time: 1691.9403 ms | Train loss: 2.9154 | Val loss: 2.9282
# ====> Epoch 54 | Train time: 1667.5453 ms| End time: 1697.2892 ms | Train loss: 2.9154 | Val loss: 2.9282
# ====> Epoch 55 | Train time: 1668.7224 ms| End time: 1698.2591 ms | Train loss: 2.9155 | Val loss: 2.9282
# ====> Epoch 56 | Train time: 1689.6858 ms| End time: 1715.5638 ms | Train loss: 2.9154 | Val loss: 2.9282
# ====> Epoch 57 | Train time: 1695.5419 ms| End time: 1721.4899 ms | Train loss: 2.9154 | Val loss: 2.9282
# ====> Epoch 58 | Train time: 1657.8264 ms| End time: 1683.5301 ms | Train loss: 2.9154 | Val loss: 2.9282
# ====> Epoch 59 | Train time: 1662.3583 ms| End time: 1688.2675 ms | Train loss: 2.9153 | Val loss: 2.9282
# ====> Epoch 60 | Train time: 1682.0068 ms| End time: 1711.7496 ms | Train loss: 2.9153 | Val loss: 2.9282
# ====> Epoch 61 | Train time: 1608.0129 ms| End time: 1637.4335 ms | Train loss: 2.9153 | Val loss: 2.9281
# ====> Epoch 62 | Train time: 1696.7981 ms| End time: 1722.7013 ms | Train loss: 2.9154 | Val loss: 2.9281
# ====> Epoch 63 | Train time: 1641.3152 ms| End time: 1666.9636 ms | Train loss: 2.9154 | Val loss: 2.9281
# ====> Epoch 64 | Train time: 1683.3601 ms| End time: 1709.3132 ms | Train loss: 2.9152 | Val loss: 2.9281
# ====> Epoch 65 | Train time: 1659.8272 ms| End time: 1688.9534 ms | Train loss: 2.9153 | Val loss: 2.9281
# ====> Epoch 66 | Train time: 1683.8334 ms| End time: 1709.6455 ms | Train loss: 2.9153 | Val loss: 2.9281
# ====> Epoch 67 | Train time: 1679.2054 ms| End time: 1704.9813 ms | Train loss: 2.9152 | Val loss: 2.9281
# ====> Epoch 68 | Train time: 1699.1358 ms| End time: 1724.8015 ms | Train loss: 2.9152 | Val loss: 2.9281
# ====> Epoch 69 | Train time: 1619.1871 ms| End time: 1648.8185 ms | Train loss: 2.9152 | Val loss: 2.9281
# ====> Epoch 70 | Train time: 1632.5943 ms| End time: 1662.0343 ms | Train loss: 2.9152 | Val loss: 2.9281
# ====> Epoch 71 | Train time: 1649.4594 ms| End time: 1675.2148 ms | Train loss: 2.9152 | Val loss: 2.9281
# ====> Epoch 72 | Train time: 1679.3869 ms| End time: 1705.4167 ms | Train loss: 2.9152 | Val loss: 2.9281
# ====> Epoch 73 | Train time: 1677.0291 ms| End time: 1706.4793 ms | Train loss: 2.9152 | Val loss: 2.9281
# ====> Epoch 74 | Train time: 1649.5872 ms| End time: 1675.2517 ms | Train loss: 2.9152 | Val loss: 2.9281
# ====> Epoch 75 | Train time: 1654.3894 ms| End time: 1680.1596 ms | Train loss: 2.9151 | Val loss: 2.9281
# ====> Epoch 76 | Train time: 1649.2515 ms| End time: 1678.8611 ms | Train loss: 2.9151 | Val loss: 2.9281
# ====> Epoch 77 | Train time: 1655.5278 ms| End time: 1681.2253 ms | Train loss: 2.9151 | Val loss: 2.9281
# ====> Epoch 78 | Train time: 1674.2861 ms| End time: 1704.2139 ms | Train loss: 2.9151 | Val loss: 2.9281
# ====> Epoch 79 | Train time: 1683.3639 ms| End time: 1712.6622 ms | Train loss: 2.9151 | Val loss: 2.9280
# ====> Epoch 80 | Train time: 1667.8979 ms| End time: 1693.5251 ms | Train loss: 2.9151 | Val loss: 2.9280
# ====> Epoch 81 | Train time: 1678.9055 ms| End time: 1708.5381 ms | Train loss: 2.9151 | Val loss: 2.9280
# ====> Epoch 82 | Train time: 1659.9112 ms| End time: 1685.6718 ms | Train loss: 2.9151 | Val loss: 2.9280
# ====> Epoch 83 | Train time: 1715.9064 ms| End time: 1745.6110 ms | Train loss: 2.9151 | Val loss: 2.9280
# ====> Epoch 84 | Train time: 1668.5276 ms| End time: 1698.3380 ms | Train loss: 2.9151 | Val loss: 2.9280
# ====> Epoch 85 | Train time: 1690.9575 ms| End time: 1720.8483 ms | Train loss: 2.9151 | Val loss: 2.9280
# ====> Epoch 86 | Train time: 1620.7237 ms| End time: 1650.0859 ms | Train loss: 2.9151 | Val loss: 2.9280
# ====> Epoch 87 | Train time: 1667.8255 ms| End time: 1693.2583 ms | Train loss: 2.9150 | Val loss: 2.9280
# ====> Epoch 88 | Train time: 1635.8230 ms| End time: 1661.4325 ms | Train loss: 2.9150 | Val loss: 2.9280
# ====> Epoch 89 | Train time: 1677.7236 ms| End time: 1703.5525 ms | Train loss: 2.9150 | Val loss: 2.9280
# ====> Epoch 90 | Train time: 1681.4752 ms| End time: 1707.2206 ms | Train loss: 2.9150 | Val loss: 2.9280
# ====> Epoch 91 | Train time: 1579.3123 ms| End time: 1605.2091 ms | Train loss: 2.9150 | Val loss: 2.9280
# ====> Epoch 92 | Train time: 1666.2581 ms| End time: 1695.5767 ms | Train loss: 2.9150 | Val loss: 2.9280
# ====> Epoch 93 | Train time: 1643.9257 ms| End time: 1669.5902 ms | Train loss: 2.9150 | Val loss: 2.9280
# ====> Epoch 94 | Train time: 1652.7538 ms| End time: 1682.1625 ms | Train loss: 2.9150 | Val loss: 2.9280
# ====> Epoch 95 | Train time: 1643.4762 ms| End time: 1669.5802 ms | Train loss: 2.9150 | Val loss: 2.9280
# ====> Epoch 96 | Train time: 1658.3264 ms| End time: 1687.6869 ms | Train loss: 2.9150 | Val loss: 2.9280
# ====> Epoch 97 | Train time: 1658.3517 ms| End time: 1688.1998 ms | Train loss: 2.9150 | Val loss: 2.9280
# ====> Epoch 98 | Train time: 1634.6078 ms| End time: 1664.3491 ms | Train loss: 2.9150 | Val loss: 2.9280
# ====> Epoch 99 | Train time: 1684.3195 ms| End time: 1710.0484 ms | Train loss: 2.9149 | Val loss: 2.9280
# ====> Epoch 100 | Train time: 1654.6278 ms| End time: 1684.5326 ms | Train loss: 2.9149 | Val loss: 2.9279

# %% [markdown]
# # Predict

# %%
if args.test:
    input_test = Variable(torch.Tensor(input_test).float())
    if args.cuda:
        input_test = input_test.cuda()
    
    print('Predicting...')
    recon_test, mu, logvar = model(input_test)
    
    print('Separating prediction ...')
    predicted_time, predicted_activity = getPrediction(recon_test, pad_index_test)
    
    print('Done!')
# Out:
# Predicting...
# Separating prediction ...
# Done!

# %% [markdown]
# # Evaluate

# %% [markdown]
# ## Time

# %%
#Fix predicted time
time_df = pd.DataFrame({'CaseID': caseid_test,
                        'PredictedTime': predicted_time})

groupByCase = time_df.groupby(['CaseID'])
fixed_time_df = pd.DataFrame(columns=list(time_df))

for case, group in groupByCase:
    group.iloc[0, 1] = -mean_value/std_value
    fixed_time_df = fixed_time_df.append(group)
# Out:
# /home/pllab/miniconda2/envs/pydata/lib/python3.5/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
fixed_time_df.head()
# Out:
#       CaseID  PredictedTime
# 96000  12001      -1.407447
# 96001  12001      -0.879757
# 96002  12001      -0.829012
# 96003  12001      -0.380325
# 96004  12001       0.123039

# %%
fixed_predicted_time = fixed_time_df['PredictedTime']

# %%
error = np.abs(true_time - fixed_predicted_time)
error_time_df = pd.DataFrame({'Error': error,
                              'TimeLabel': time_label_test})

# %%
precision, recall, th = precision_recall_curve(error_time_df.TimeLabel, error_time_df.Error, pos_label=1)
plt.figure(figsize=(20, 5))
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
time_threshold = np.mean(error_time_df['Error'])
print('Threshold of Time: {}'.format(time_threshold))
# Out:
# Threshold of Time: 0.05103547121562427

# %%
plotOverlapReconstructionError(error_time_df, variable='Time', output_dir=args.output_dir, save=True)

# %%
plotReconstructionError(error_time_df, variable='Time')

# %%
plotConfusionMaxtrix(error_time_df, threshold=time_threshold, variable='Time', output_dir=args.output_dir, save=True)

# %%
evalScore(error_time_df, threshold=time_threshold, variable='Time')
# Out:
# -------Evaluation of Time-------
#
#
# --Weighted Evaluation--
# Evaluation of Time
# Precision: 0.94
# Recall: 0.88
# Fscore: 0.90
#
#
# --Evaluation for each class--
# Normal
# Precision: 0.99
# Recall: 0.88
# Fscore: 0.93
#
#
# Anomaly
# Precision: 0.41
# Recall: 0.88
# Fscore: 0.56

# %%
fpr, tpr, thresholds = roc_curve(error_time_df.TimeLabel, error_time_df.Error, pos_label=1)
roc_auc = auc(fpr, tpr)

#plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig(args.output_dir + 'ROC_time.png')
plt.show();

# %%
#get submission
if args.scaler == 'standardization':
    inverse_scaled_time = [x*std_value+mean_value for x in fixed_predicted_time]
else:
    inverse_scaled_time = [x*(max_value-min_value)+min_value for x in fixed_predicted_time]
    
predicted_time_label_test = [1 if e > time_threshold else 0 for e in error_time_df.Error.values]

submission_time = pd.DataFrame({'AnomalousDuration': anomalous_df_test['AnomalousDuration'].copy(),
                                'Activity': normal_df_test['Activity'].copy(),
                                'AnomalousCumDuration': anomalous_df_test['AnomalousCumDuration'].copy(),
                                'PredictedCumDuration': inverse_scaled_time,
                                'TimeLabel': time_label_test,
                                'PredictedTimeLabel': predicted_time_label_test})

# %%
submission_time.head()
# Out:
#          Activity  AnomalousCumDuration  AnomalousDuration  \
# 96000  Activity A                   0.0                0.0
# 96001  Activity D                3600.0             3600.0
# 96002  Activity C                3600.0                0.0
# 96003  Activity B                7200.0             3600.0
# 96004  Activity E               10800.0             3600.0
#
#        PredictedCumDuration  PredictedTimeLabel TimeLabel
# 96000              0.000000                   0         0
# 96001           3788.726094                   0         0
# 96002           4153.067231                   1         0
# 96003           7374.573015                   0         0
# 96004          10988.646308                   0         0

# %%
groupByActivity = submission_time.groupby(['Activity'])

for act, group in groupByActivity:
    plotDurationofPredictedTimeLabel(act, group, statistics_storage, args.output_dir, True)

# %%
submission_time.head()
# Out:
#          Activity  AnomalousCumDuration  AnomalousDuration  \
# 96000  Activity A                   0.0                0.0
# 96001  Activity D                3600.0             3600.0
# 96002  Activity C                3600.0                0.0
# 96003  Activity B                7200.0             3600.0
# 96004  Activity E               10800.0             3600.0
#
#        PredictedCumDuration  PredictedTimeLabel TimeLabel
# 96000              0.000000                   0         0
# 96001           3788.726094                   0         0
# 96002           4153.067231                   1         0
# 96003           7374.573015                   0         0
# 96004          10988.646308                   0         0

# %%
act_list = [i for i in submission_time['Activity'].unique()]
false_positive_df = submission_time[(submission_time['PredictedTimeLabel']== 1)&(submission_time['TimeLabel']== 0)]
false_negative_df = submission_time[(submission_time['PredictedTimeLabel']== 0)&(submission_time['TimeLabel']== 1)]

for act in act_list:
    plotFalseDuration(false_positive_df, false_negative_df, act, statistics_storage)

# %% [markdown]
# ## Activity

# %% [markdown]
# ### Threshold

# %%
# error = np.mean(np.power(true_act - predicted_activity, 2), axis = 1)
error = np.mean(np.abs(true_act - predicted_activity), axis = 1)
error_activity_df = pd.DataFrame({'Error': error,
                                  'ActivityLabel': activity_label_test})

# %%
error_activity_df.head()
# Out:
#        ActivityLabel     Error
# 96000              0  0.157297
# 96001              0  0.171952
# 96002              0  0.171822
# 96003              0  0.157414
# 96004              1  0.182538

# %%
precision, recall, th = precision_recall_curve(error_activity_df.ActivityLabel, error_activity_df.Error, pos_label=1)
plt.figure(figsize=(20, 5))
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
activity_threshold = np.mean(error_activity_df['Error'])
print('Threshold of Activity: {}'.format(activity_threshold))
# Out:
# Threshold of Activity: 0.16517615422712018

# %%
plotConfusionMaxtrix(error_activity_df, activity_threshold, variable='Activity', output_dir=args.output_dir, save=True)

# %%
plotOverlapReconstructionError(error_activity_df, variable='Activity', output_dir=args.output_dir, save=True)

# %%
plotReconstructionError(error_activity_df)

# %%
evalScore(error_activity_df, 0.24, variable='Activity')
# Out:
# -------Evaluation of Activity-------
#
#
# --Weighted Evaluation--
# Evaluation of Activity
# Precision: 0.81
# Recall: 0.90
# Fscore: 0.85
#
#
# --Evaluation for each class--
# Normal
# Precision: 0.90
# Recall: 1.00
# Fscore: 0.95
#
#
# Anomaly
# Precision: 0.00
# Recall: 0.00
# Fscore: 0.00
# /home/pllab/miniconda2/envs/pydata/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
fpr, tpr, thresholds = roc_curve(error_activity_df.ActivityLabel, error_activity_df.Error, pos_label=1)
roc_auc = auc(fpr, tpr)

#plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig(args.output_dir+'ROC_Act.png')
plt.show();

# %% [markdown]
# ### Argmax

# %%
# evaluate based on classification
predicted_act_df = pd.DataFrame(data=predicted_activity, columns=list(true_act))
predicted_act_label = predicted_act_df.idxmax(axis=1)
true_act_label = true_act.idxmax(axis=1)
predicted_time_label = [0 if a==b else 1 for a, b in zip(true_act_label,predicted_act_label)]

# %%
#plot confusion matrix
LABELS = ['Normal', 'Anomaly']
matrix = confusion_matrix(error_activity_df.ActivityLabel.astype('uint8'), predicted_time_label)
plt.figure(figsize=(7, 7))
sns.heatmap(matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title('Confusion matrix of Activity')
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
score = precision_recall_fscore_support(error_activity_df.ActivityLabel.astype('uint8'), predicted_time_label, average='weighted')
    
print('-------Evaluation of Activity-------')
print('\n')
print('--Weighted Evaluation--')
print('Evaluation')
print('Precision: {:.2f}'.format(score[0]))
print('Recall: {:.2f}'.format(score[1]))
print('Fscore: {:.2f}'.format(score[2]))
print('\n')
score_1 = precision_recall_fscore_support(error_activity_df.ActivityLabel.astype('uint8'), predicted_time_label)
print('--Evaluation for each class--')
print('Normal')
print('Precision: {:.2f}'.format(score_1[0][0]))
print('Recall: {:.2f}'.format(score_1[1][0]))
print('Fscore: {:.2f}'.format(score_1[2][0]))
print('\n')
print('Anomaly')
print('Precision: {:.2f}'.format(score_1[0][1]))
print('Recall: {:.2f}'.format(score_1[1][1]))
print('Fscore: {:.2f}'.format(score_1[2][1]))
# Out:
# -------Evaluation of Activity-------
#
#
# --Weighted Evaluation--
# Evaluation
# Precision: 0.93
# Recall: 0.81
# Fscore: 0.84
#
#
# --Evaluation for each class--
# Normal
# Precision: 1.00
# Recall: 0.79
# Fscore: 0.88
#
#
# Anomaly
# Precision: 0.35
# Recall: 0.98
# Fscore: 0.51

# %%
from sklearn.metrics import accuracy_score
accuracy_score(true_act_label, predicted_act_label)
# Out:
# 0.71229166666666666

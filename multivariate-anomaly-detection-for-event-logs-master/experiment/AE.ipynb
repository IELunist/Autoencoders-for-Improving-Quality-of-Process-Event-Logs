# %% [markdown]
# This is the implementation of [**Autoencoder**](http://www.iro.umontreal.ca/~lisa/bib/pub_subject/language/pointeurs/bengio+lecun-chapter2007.pdf)

# %%
import importlib
import argparse
import os, sys
import argparse
import pandas as pd
import numpy as np
import pickle
import time

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, roc_curve, auc, precision_recall_curve


# %matplotlib inline

# %%
import torch
import torch.utils.data
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import torch.optim.lr_scheduler
from torch.autograd import Variable
from torchvision import transforms

# %%
sys.path.insert(0, './../utils/')
from utils import *
from models import *

# %%
#Define parser
#name = 'bpi_2013'
name = 'bpi_2012'
#name = 'small_log'
#name = 'large_log'

parser = {
    'train': True,
    'test': True,
    'model_class': 'AE_dropout', #AE_dropout
    'model_name': '',
    'data_dir': '../data/',
    'data_file': name + '.csv',
    'anomaly_pct': 0.1,
    'scaler': 'standardization',
    'input_dir': '../input/{}/'.format(name), 
    'batch_size' : 16,
    'epochs' : 100,
    'no_cuda' : False,
    'seed' : 7,
    'layer1': 300,
    'layer2': 100,
    'lr': 0.001,
    'betas': (0.9, 0.999),   
    'lr_decay': 0.99,
}

args = argparse.Namespace(**parser)
args.output_dir = './output/{0}_{1}_{2}/'.format(name, args.anomaly_pct, args.model_class)

# %%
if not os.path.isdir(args.output_dir):
    os.makedirs(args.output_dir)

# %%
args.cuda = not args.no_cuda and torch.cuda.is_available()
kwargs = {'num_workers': 2, 'pin_memory': True} if args.cuda else {}

# %%
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)

# %%
preprocessed_data_name = os.path.join(args.input_dir, 'preprocessed_data_{}.pkl'.format(args.anomaly_pct))
with open(preprocessed_data_name, 'rb') as f:
    input_train = pickle.load(f)
    input_val = pickle.load(f)
    input_test = pickle.load(f)
    pad_index_train = pickle.load(f)
    pad_index_val = pickle.load(f)
    pad_index_test = pickle.load(f)
    activity_label_test = pickle.load(f)
    time_label_test = pickle.load(f)
    train_case_num = pickle.load(f)
    val_case_num = pickle.load(f)
    test_case_num = pickle.load(f)
    train_row_num = pickle.load(f)
    val_row_num = pickle.load(f)
    test_row_num = pickle.load(f)
    min_value = pickle.load(f)
    max_value = pickle.load(f)
    mean_value = pickle.load(f)
    std_value = pickle.load(f)
    cols = pickle.load(f)
    statistics_storage = pickle.load(f)
    true_time = pickle.load(f)
    true_act = pickle.load(f)
    full_true_time = pickle.load(f)
    full_true_act = pickle.load(f)

# %% [markdown]
# # Load data

# %%
#train
input_trainLoader = torch.utils.data.DataLoader(input_train, batch_size=args.batch_size, shuffle=False, num_workers=2)
pad_index_trainLoader = torch.utils.data.DataLoader(pad_index_train, batch_size=args.batch_size, shuffle=False, num_workers=2)

# %%
#df
normal_df_name = os.path.join(args.input_dir, 'normal_df_{}.csv'.format(args.anomaly_pct))
normal_df = pd.read_csv(normal_df_name)

anomalous_df_name = os.path.join(args.input_dir, 'anomolous_df_{}.csv'.format(args.anomaly_pct))
anomalous_df = pd.read_csv(anomalous_df_name)

#test
caseid_test = normal_df['CaseID'][-test_row_num:]
normal_df_test = normal_df[-test_row_num:]
anomalous_df_test = anomalous_df[-test_row_num:]

# %%
normal_df.head()
# Out:
#    CaseID                         Activity        CompleteTimestamp  \
# 0       1             A_SUBMITTED-COMPLETE  2011-10-01 07:38:44.546
# 1       1       A_PARTLYSUBMITTED-COMPLETE  2011-10-01 07:38:44.880
# 2       1           A_PREACCEPTED-COMPLETE  2011-10-01 07:39:37.906
# 3       1  W_Completeren aanvraag-SCHEDULE  2011-10-01 07:39:38.875
# 4       1     W_Completeren aanvraag-START  2011-10-01 18:36:46.437
#
#     Duration  CumDuration
# 0      0.000        0.000
# 1      0.334        0.334
# 2     53.026       53.360
# 3      0.969       54.329
# 4  39427.562    39481.891

# %%
anomalous_df.head()
# Out:
#    CaseID                AnomalousActivity  AnomalousCompleteTimestamp  \
# 0       1             A_SUBMITTED-COMPLETE  2011-10-01 07:38:44.546000
# 1       1       A_PARTLYSUBMITTED-COMPLETE  2011-10-01 07:38:44.880000
# 2       1           A_PREACCEPTED-COMPLETE  2011-10-01 07:39:37.906000
# 3       1  W_Completeren aanvraag-SCHEDULE  2011-10-01 07:39:38.875000
# 4       1     W_Completeren aanvraag-START  2011-10-01 18:36:46.437000
#
#    AnomalousDuration  AnomalousCumDuration  ActivityLabel  TimeLabel
# 0              0.000                 0.000              0          0
# 1              0.334                 0.334              0          0
# 2             53.026                53.360              0          0
# 3              0.969                54.329              0          0
# 4          39427.562             39481.891              0          0

# %% [markdown]
# # Build model

# %% [markdown]
# ## Define model

# %%
if args.model_class == 'AE':
    model = AE(input_train.shape, args.layer1, args.layer2)
    
if args.model_class == 'AE_dropout':
    model = AE_dropout(input_train.shape, args.layer1, args.layer2)

if args.cuda:
    model.cuda()

# %%
model
# Out:
# AE_dropout (
#   (fc1): Linear (6475 -> 300)
#   (fc2): Linear (300 -> 100)
#   (fc3): Linear (100 -> 300)
#   (fc4): Linear (300 -> 6475)
#   (dout): Dropout (p = 0.2)
#   (tanh): Tanh ()
# )

# %% [markdown]
# ## Define loss

# %%
def loss_function(recon_x, x, pad_index):
    MSE = F.mse_loss(recon_x*pad_index, x*pad_index, size_average=False) 
    return MSE

# %% [markdown]
# ## Define optimizer

# %%
optimizer = optim.Adam(model.parameters(), lr=args.lr, betas=args.betas)

# %%
#Adjust learning rate per epoch: http://pytorch.org/docs/master/optim.html?highlight=lr_scheduler#torch.optim.lr_scheduler.LambdaLR

lambda1 = lambda epoch: args.lr_decay ** epoch
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=[lambda1])

# %% [markdown]
# # Utils

# %%
def save_model(model, epoch, score):
    model_file = os.path.join(args.output_dir, 'model_{}_epoch{}_score{:.4f}.pth'.format(args.model_class, epoch, score))
    torch.save(model.state_dict(), model_file)

# %%
def load_model(model, model_name):
    model_file = os.path.join(args.output_dir, model_name)
    assert os.path.isfile(model_file), 'Error: no model found!'
    model_state = torch.load(model_file)
    model.load_state_dict(model_state)

# %%
def val(model, input_val, pad_index_val):
    model.eval()
    input_val = Variable(torch.Tensor(input_val).float())
    pad_index_val = Variable(torch.Tensor(pad_index_val).float())
    
    if args.cuda:
        input_val = input_val.cuda()
        pad_index_val = pad_index_val.cuda()
    
    recon_val = model(input_val)    
    loss = loss_function(recon_val, input_val, pad_index_val)
    return loss.data[0]/len(input_test.data)

# %% [markdown]
# # Train

# %%
def train(epoch, model, optimizer):
    model.train()
    train_loss = 0
    for batch_idx, (batch_data, batch_index) in enumerate(zip(input_trainLoader, pad_index_trainLoader)):
        
        batch_data = Variable(batch_data.float())
        batch_index = Variable(batch_index.float())

        if args.cuda:
            batch_data = batch_data.cuda()
            batch_index = batch_index.cuda()
            
        optimizer.zero_grad()
        
        recon_data = model(batch_data)
        
        loss = loss_function(recon_data, batch_data, batch_index)
        
        loss.backward()
        train_loss += loss.data[0]
        optimizer.step()
        
    return train_loss / len(input_trainLoader.dataset)

# %%
if args.train:
    for epoch in range(1, args.epochs + 1):
        init = time.time()
        
        #method 1 scheduler
        scheduler.step()
        
        train_loss = train(epoch, model, optimizer)
        end_train = time.time()
        val_score = val(model, input_val, pad_index_val)
        
        '''
        # To save model
        if epoch == 1:
            current_best = val_score
            save_model(model, epoch, val_score)
        
        else:
            if val_score < current_best:
                current_best = val_score
                save_model(model, epoch, val_score)
        '''
        
        end = time.time()
        print('====> Epoch {} | Train time: {:.4f} ms| End time: {:.4f} ms | Train loss: {:.4f} | Val loss: {:.4f}'.
              format(epoch, (end_train-init)*1000, (end-init)*1000, train_loss, val_score))
else:
    load_model(model, args.model_name)
# Out:
# ====> Epoch 1 | Train time: 1698.5452 ms| End time: 3036.2639 ms | Train loss: 29.3311 | Val loss: 18.4107
# ====> Epoch 2 | Train time: 1537.3888 ms| End time: 2866.3790 ms | Train loss: 23.3025 | Val loss: 18.3386
# ====> Epoch 3 | Train time: 1542.4740 ms| End time: 2884.9881 ms | Train loss: 23.2476 | Val loss: 16.7314
# ====> Epoch 4 | Train time: 1525.3885 ms| End time: 2869.0510 ms | Train loss: 22.8955 | Val loss: 17.5893
# ====> Epoch 5 | Train time: 1539.6032 ms| End time: 2873.3907 ms | Train loss: 21.6304 | Val loss: 16.0720
# ====> Epoch 6 | Train time: 1496.8140 ms| End time: 2832.1874 ms | Train loss: 21.3513 | Val loss: 16.0074
# ====> Epoch 7 | Train time: 1514.0126 ms| End time: 2854.8751 ms | Train loss: 20.4407 | Val loss: 15.8153
# ====> Epoch 8 | Train time: 1578.4855 ms| End time: 2914.9516 ms | Train loss: 19.3626 | Val loss: 15.4060
# ====> Epoch 9 | Train time: 1524.1432 ms| End time: 2861.1140 ms | Train loss: 19.4095 | Val loss: 16.3645
# ====> Epoch 10 | Train time: 1534.2739 ms| End time: 2874.1393 ms | Train loss: 19.3260 | Val loss: 14.6649
# ====> Epoch 11 | Train time: 1557.6692 ms| End time: 2892.0066 ms | Train loss: 18.6512 | Val loss: 14.4843
# ====> Epoch 12 | Train time: 1545.0525 ms| End time: 2888.3369 ms | Train loss: 18.2535 | Val loss: 14.3620
# ====> Epoch 13 | Train time: 1544.1139 ms| End time: 2884.6173 ms | Train loss: 18.3085 | Val loss: 14.4589
# ====> Epoch 14 | Train time: 1550.2822 ms| End time: 2884.4070 ms | Train loss: 18.1244 | Val loss: 13.6835
# ====> Epoch 15 | Train time: 1553.7636 ms| End time: 2910.4528 ms | Train loss: 17.4915 | Val loss: 13.8821
# ====> Epoch 16 | Train time: 1495.2877 ms| End time: 2848.7468 ms | Train loss: 18.0134 | Val loss: 13.6040
# ====> Epoch 17 | Train time: 1524.0502 ms| End time: 2858.8300 ms | Train loss: 16.6012 | Val loss: 13.2531
# ====> Epoch 18 | Train time: 1531.1830 ms| End time: 2865.6633 ms | Train loss: 16.3237 | Val loss: 13.5257
# ====> Epoch 19 | Train time: 1549.9907 ms| End time: 2889.7204 ms | Train loss: 16.5033 | Val loss: 13.6953
# ====> Epoch 20 | Train time: 1560.4992 ms| End time: 2900.6181 ms | Train loss: 16.0943 | Val loss: 12.9803
# ====> Epoch 21 | Train time: 1540.4117 ms| End time: 2880.2500 ms | Train loss: 16.0783 | Val loss: 13.2578
# ====> Epoch 22 | Train time: 1564.5289 ms| End time: 2898.1469 ms | Train loss: 15.6111 | Val loss: 12.8646
# ====> Epoch 23 | Train time: 1532.7837 ms| End time: 2866.2593 ms | Train loss: 15.5083 | Val loss: 13.0364
# ====> Epoch 24 | Train time: 1573.1704 ms| End time: 2916.4059 ms | Train loss: 15.4087 | Val loss: 13.0503
# ====> Epoch 25 | Train time: 1538.4078 ms| End time: 2879.4231 ms | Train loss: 15.2286 | Val loss: 12.7203
# ====> Epoch 26 | Train time: 1573.9808 ms| End time: 2902.7870 ms | Train loss: 15.4507 | Val loss: 12.9683
# ====> Epoch 27 | Train time: 1539.7215 ms| End time: 2879.6194 ms | Train loss: 15.2026 | Val loss: 12.9487
# ====> Epoch 28 | Train time: 1517.4105 ms| End time: 2854.9409 ms | Train loss: 15.2194 | Val loss: 13.0184
# ====> Epoch 29 | Train time: 1552.2001 ms| End time: 2898.6530 ms | Train loss: 15.1088 | Val loss: 12.6214
# ====> Epoch 30 | Train time: 1525.6922 ms| End time: 2877.7342 ms | Train loss: 15.1086 | Val loss: 12.8240
# ====> Epoch 31 | Train time: 1515.6138 ms| End time: 2852.7524 ms | Train loss: 14.9749 | Val loss: 12.7594
# ====> Epoch 32 | Train time: 1556.5343 ms| End time: 2894.3784 ms | Train loss: 14.8719 | Val loss: 12.5727
# ====> Epoch 33 | Train time: 1550.9126 ms| End time: 2886.7455 ms | Train loss: 14.8138 | Val loss: 12.9179
# ====> Epoch 34 | Train time: 1503.4251 ms| End time: 2846.4859 ms | Train loss: 14.8623 | Val loss: 12.4690
# ====> Epoch 35 | Train time: 1535.8248 ms| End time: 2867.5568 ms | Train loss: 14.7499 | Val loss: 12.5837
# ====> Epoch 36 | Train time: 1501.9455 ms| End time: 2837.1141 ms | Train loss: 14.6156 | Val loss: 12.6404
# ====> Epoch 37 | Train time: 1524.9286 ms| End time: 2886.3113 ms | Train loss: 14.5941 | Val loss: 12.2558
# ====> Epoch 38 | Train time: 1510.8144 ms| End time: 2857.5623 ms | Train loss: 14.6847 | Val loss: 12.8304
# ====> Epoch 39 | Train time: 1532.8684 ms| End time: 2870.6043 ms | Train loss: 14.6352 | Val loss: 12.6669
# ====> Epoch 40 | Train time: 1520.8189 ms| End time: 2856.9126 ms | Train loss: 14.5483 | Val loss: 12.3788
# ====> Epoch 41 | Train time: 1544.4386 ms| End time: 2875.1881 ms | Train loss: 14.6067 | Val loss: 12.4874
# ====> Epoch 42 | Train time: 1522.6254 ms| End time: 2860.1162 ms | Train loss: 14.3046 | Val loss: 12.1185
# ====> Epoch 43 | Train time: 1519.8057 ms| End time: 2876.6534 ms | Train loss: 14.3548 | Val loss: 12.1805
# ====> Epoch 44 | Train time: 1553.8323 ms| End time: 2904.6111 ms | Train loss: 14.0676 | Val loss: 12.3960
# ====> Epoch 45 | Train time: 1550.5412 ms| End time: 2890.2507 ms | Train loss: 14.3156 | Val loss: 12.3553
# ====> Epoch 46 | Train time: 1504.4432 ms| End time: 2839.3393 ms | Train loss: 14.2634 | Val loss: 11.9421
# ====> Epoch 47 | Train time: 1546.0839 ms| End time: 2885.6838 ms | Train loss: 14.1356 | Val loss: 11.9937
# ====> Epoch 48 | Train time: 1517.8039 ms| End time: 2852.6950 ms | Train loss: 14.1278 | Val loss: 12.4394
# ====> Epoch 49 | Train time: 1548.4335 ms| End time: 2878.1555 ms | Train loss: 14.0722 | Val loss: 11.9570
# ====> Epoch 50 | Train time: 1543.9310 ms| End time: 2882.2441 ms | Train loss: 13.8777 | Val loss: 12.1460
# ====> Epoch 51 | Train time: 1540.6168 ms| End time: 2884.9757 ms | Train loss: 13.9061 | Val loss: 11.8685
# ====> Epoch 52 | Train time: 1555.3665 ms| End time: 2892.5512 ms | Train loss: 13.8661 | Val loss: 12.1151
# ====> Epoch 53 | Train time: 1558.3134 ms| End time: 2894.9192 ms | Train loss: 13.7427 | Val loss: 12.0306
# ====> Epoch 54 | Train time: 1535.6362 ms| End time: 2878.7544 ms | Train loss: 13.8552 | Val loss: 11.9018
# ====> Epoch 55 | Train time: 1532.5840 ms| End time: 2868.6368 ms | Train loss: 13.6846 | Val loss: 11.9191
# ====> Epoch 56 | Train time: 1541.6911 ms| End time: 2883.9025 ms | Train loss: 13.6683 | Val loss: 11.9222
# ====> Epoch 57 | Train time: 1563.6892 ms| End time: 2896.1511 ms | Train loss: 13.7830 | Val loss: 11.9572
# ====> Epoch 58 | Train time: 1532.2239 ms| End time: 2864.2352 ms | Train loss: 13.6226 | Val loss: 11.8853
# ====> Epoch 59 | Train time: 1520.3300 ms| End time: 2853.8651 ms | Train loss: 13.5705 | Val loss: 11.8871
# ====> Epoch 60 | Train time: 1506.8500 ms| End time: 2838.9404 ms | Train loss: 13.5480 | Val loss: 11.6852
# ====> Epoch 61 | Train time: 1544.7183 ms| End time: 2869.6141 ms | Train loss: 13.6038 | Val loss: 12.1355
# ====> Epoch 62 | Train time: 1526.9632 ms| End time: 2856.1134 ms | Train loss: 13.4662 | Val loss: 11.8151
# ====> Epoch 63 | Train time: 1525.8477 ms| End time: 2863.2245 ms | Train loss: 13.3944 | Val loss: 11.8114
# ====> Epoch 64 | Train time: 1538.1455 ms| End time: 2876.1339 ms | Train loss: 13.4670 | Val loss: 11.6699
# ====> Epoch 65 | Train time: 1545.0344 ms| End time: 2879.3237 ms | Train loss: 13.4809 | Val loss: 11.7040
# ====> Epoch 66 | Train time: 1535.1369 ms| End time: 2864.4259 ms | Train loss: 13.5268 | Val loss: 11.8457
# ====> Epoch 67 | Train time: 1567.8780 ms| End time: 2901.3543 ms | Train loss: 13.4406 | Val loss: 11.7492
# ====> Epoch 68 | Train time: 1562.8977 ms| End time: 2904.8228 ms | Train loss: 13.3462 | Val loss: 11.5369
# ====> Epoch 69 | Train time: 1520.9818 ms| End time: 2859.4997 ms | Train loss: 13.2320 | Val loss: 11.7872
# ====> Epoch 70 | Train time: 1532.3999 ms| End time: 2868.9141 ms | Train loss: 13.2527 | Val loss: 11.5582
# ====> Epoch 71 | Train time: 1532.4366 ms| End time: 2870.4886 ms | Train loss: 13.2488 | Val loss: 11.8475
# ====> Epoch 72 | Train time: 1529.2330 ms| End time: 2864.5251 ms | Train loss: 13.1482 | Val loss: 11.5693
# ====> Epoch 73 | Train time: 1508.4181 ms| End time: 2853.6823 ms | Train loss: 13.2088 | Val loss: 11.5061
# ====> Epoch 74 | Train time: 1497.7784 ms| End time: 2840.0252 ms | Train loss: 13.2513 | Val loss: 11.6665
# ====> Epoch 75 | Train time: 1508.6377 ms| End time: 2849.3350 ms | Train loss: 13.0934 | Val loss: 11.4688
# ====> Epoch 76 | Train time: 1527.5710 ms| End time: 2873.4112 ms | Train loss: 13.3130 | Val loss: 12.0170
# ====> Epoch 77 | Train time: 1532.9974 ms| End time: 2873.3926 ms | Train loss: 12.9738 | Val loss: 11.4268
# ====> Epoch 78 | Train time: 1545.0344 ms| End time: 2901.1507 ms | Train loss: 12.8712 | Val loss: 11.5092
# ====> Epoch 79 | Train time: 1599.5274 ms| End time: 2941.2515 ms | Train loss: 13.0098 | Val loss: 11.5636
# ====> Epoch 80 | Train time: 1554.4031 ms| End time: 2901.2671 ms | Train loss: 12.8796 | Val loss: 11.4468
# ====> Epoch 81 | Train time: 1487.8211 ms| End time: 2813.0083 ms | Train loss: 12.9502 | Val loss: 11.4839
# ====> Epoch 82 | Train time: 1529.9640 ms| End time: 2868.0353 ms | Train loss: 12.8531 | Val loss: 11.7547
# ====> Epoch 83 | Train time: 1566.4005 ms| End time: 2897.3122 ms | Train loss: 12.9107 | Val loss: 11.5612
# ====> Epoch 84 | Train time: 1533.1273 ms| End time: 2871.7747 ms | Train loss: 12.9378 | Val loss: 11.2728
# ====> Epoch 85 | Train time: 1522.9685 ms| End time: 2856.9474 ms | Train loss: 12.7446 | Val loss: 11.5624
# ====> Epoch 86 | Train time: 1526.4933 ms| End time: 2860.5564 ms | Train loss: 12.9075 | Val loss: 11.2483
# ====> Epoch 87 | Train time: 1548.4307 ms| End time: 2889.6391 ms | Train loss: 12.8528 | Val loss: 11.4875
# ====> Epoch 88 | Train time: 1544.4970 ms| End time: 2878.5615 ms | Train loss: 12.8470 | Val loss: 11.3371
# ====> Epoch 89 | Train time: 1530.8940 ms| End time: 2859.7307 ms | Train loss: 12.7632 | Val loss: 11.4073
# ====> Epoch 90 | Train time: 1532.7415 ms| End time: 2863.4646 ms | Train loss: 12.8078 | Val loss: 11.3534
# ====> Epoch 91 | Train time: 1565.2928 ms| End time: 2907.4650 ms | Train loss: 12.7266 | Val loss: 11.4408
# ====> Epoch 92 | Train time: 1549.2558 ms| End time: 2884.5329 ms | Train loss: 12.5464 | Val loss: 11.5633
# ====> Epoch 93 | Train time: 1532.3141 ms| End time: 2869.5977 ms | Train loss: 12.6708 | Val loss: 11.3676
# ====> Epoch 94 | Train time: 1523.9301 ms| End time: 2863.8163 ms | Train loss: 12.6993 | Val loss: 11.2421
# ====> Epoch 95 | Train time: 1544.2860 ms| End time: 2881.4681 ms | Train loss: 12.5386 | Val loss: 11.2905
# ====> Epoch 96 | Train time: 1520.6814 ms| End time: 2864.6357 ms | Train loss: 12.6871 | Val loss: 11.3494
# ====> Epoch 97 | Train time: 1503.3870 ms| End time: 2840.7218 ms | Train loss: 12.5663 | Val loss: 11.2167
# ====> Epoch 98 | Train time: 1501.3380 ms| End time: 2838.2616 ms | Train loss: 12.4777 | Val loss: 11.2814
# ====> Epoch 99 | Train time: 1526.1657 ms| End time: 2865.2892 ms | Train loss: 12.4579 | Val loss: 11.4104
# ====> Epoch 100 | Train time: 1535.6033 ms| End time: 2880.6283 ms | Train loss: 12.4769 | Val loss: 11.0988

# %% [markdown]
# # Predict

# %%
if args.test:
    input_test = Variable(torch.Tensor(input_test).float())
    if args.cuda:
        input_test = input_test.cuda()
    
    print('Predicting...')
    recon_test = model(input_test)
    
    print('Separating prediction ...')
    predicted_time, predicted_activity = getPrediction(recon_test, pad_index_test)
    
    print('Done!')
# Out:
# Predicting...
# Separating prediction ...
# Done!

# %% [markdown]
# # Evaluate

# %% [markdown]
# ## Time

# %%
#Fix predicted time
time_df = pd.DataFrame({'CaseID': caseid_test,
                        'PredictedTime': predicted_time})

groupByCase = time_df.groupby(['CaseID'])
fixed_time_df = pd.DataFrame(columns=list(time_df))

for case, group in groupByCase:
    group.iloc[0, 1] = -mean_value/std_value
    fixed_time_df = fixed_time_df.append(group)
# Out:
# /home/pllab/miniconda2/envs/pydata/lib/python3.5/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
fixed_time_df.head()
# Out:
#        CaseID  PredictedTime
# 214377  10470      -0.720081
# 214378  10470      -0.629216
# 214379  10470      -0.635703
# 214380  10471      -0.720081
# 214381  10471      -0.584909

# %%
fixed_predicted_time = fixed_time_df['PredictedTime']

# %%
error = np.abs(true_time - fixed_predicted_time)
error_time_df = pd.DataFrame({'Error': error,
                              'TimeLabel': time_label_test})

# %%
precision, recall, th = precision_recall_curve(error_time_df.TimeLabel, error_time_df.Error, pos_label=1)
plt.figure(figsize=(20, 5))
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
time_threshold = np.mean(error_time_df['Error'])
print('Threshold of Time: {}'.format(time_threshold))
# Out:
# Threshold of Time: 0.16114638610982254

# %%
plotOverlapReconstructionError(error_time_df, variable='Time', output_dir=args.output_dir, save=True)

# %%
plotReconstructionError(error_time_df, variable='Time')

# %%
plotConfusionMaxtrix(error_time_df, threshold=time_threshold, variable='Time', output_dir=args.output_dir, save=True)

# %%
evalScore(error_time_df, threshold=time_threshold, variable='Time')
# Out:
# -------Evaluation of Time-------
#
#
# --Weighted Evaluation--
# Evaluation of Time
# Precision: 0.85
# Recall: 0.66
# Fscore: 0.73
#
#
# --Evaluation for each class--
# Normal
# Precision: 0.93
# Recall: 0.68
# Fscore: 0.78
#
#
# Anomaly
# Precision: 0.13
# Recall: 0.47
# Fscore: 0.21

# %%
fpr, tpr, thresholds = roc_curve(error_time_df.TimeLabel, error_time_df.Error, pos_label=1)
roc_auc = auc(fpr, tpr)

#plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig(args.output_dir + 'ROC_time.png')
plt.show();

# %%
#get submission
if args.scaler == 'standardization':
    inverse_scaled_time = [x*std_value+mean_value for x in fixed_predicted_time]
else:
    inverse_scaled_time = [x*(max_value-min_value)+min_value for x in fixed_predicted_time]
    
predicted_time_label_test = [1 if e > time_threshold else 0 for e in error_time_df.Error.values]

submission_time = pd.DataFrame({'AnomalousDuration': anomalous_df_test['AnomalousDuration'].copy(),
                                'Activity': normal_df_test['Activity'].copy(),
                                'AnomalousCumDuration': anomalous_df_test['AnomalousCumDuration'].copy(),
                                'PredictedCumDuration': inverse_scaled_time,
                                'TimeLabel': time_label_test,
                                'PredictedTimeLabel': predicted_time_label_test})

# %%
submission_time.head()
# Out:
#                           Activity  AnomalousCumDuration  AnomalousDuration  \
# 214377        A_SUBMITTED-COMPLETE                 0.000              0.000
# 214378  A_PARTLYSUBMITTED-COMPLETE                 0.276              0.276
# 214379         A_DECLINED-COMPLETE                31.917             31.641
# 214380        A_SUBMITTED-COMPLETE                 0.000              0.000
# 214381  A_PARTLYSUBMITTED-COMPLETE                 0.555              0.555
#
#         PredictedCumDuration  PredictedTimeLabel TimeLabel
# 214377              0.000000                   0         0
# 214378          88955.131445                   0         0
# 214379          82604.956650                   0         0
# 214380              0.000000                   0         0
# 214381         132331.051126                   0         0

# %%
groupByActivity = submission_time.groupby(['Activity'])

for act, group in groupByActivity:
    plotDurationofPredictedTimeLabel(act, group, statistics_storage, args.output_dir, True)

# %%
submission_time.head()
# Out:
#                           Activity  AnomalousCumDuration  AnomalousDuration  \
# 214377        A_SUBMITTED-COMPLETE                 0.000              0.000
# 214378  A_PARTLYSUBMITTED-COMPLETE                 0.276              0.276
# 214379         A_DECLINED-COMPLETE                31.917             31.641
# 214380        A_SUBMITTED-COMPLETE                 0.000              0.000
# 214381  A_PARTLYSUBMITTED-COMPLETE                 0.555              0.555
#
#         PredictedCumDuration  PredictedTimeLabel TimeLabel
# 214377              0.000000                   0         0
# 214378          88955.131445                   0         0
# 214379          82604.956650                   0         0
# 214380              0.000000                   0         0
# 214381         132331.051126                   0         0

# %%
act_list = [i for i in submission_time['Activity'].unique()]
false_positive_df = submission_time[(submission_time['PredictedTimeLabel']== 1)&(submission_time['TimeLabel']== 0)]
false_negative_df = submission_time[(submission_time['PredictedTimeLabel']== 0)&(submission_time['TimeLabel']== 1)]

for act in act_list:
    plotFalseDuration(false_positive_df, false_negative_df, act, statistics_storage)

# %% [markdown]
# ## Activity

# %%
#error = np.mean(np.power(true_act - predicted_activity, 2), axis = 1)
error = np.mean(np.abs(true_act - predicted_activity), axis = 1)
error_activity_df = pd.DataFrame({'Error': error,
                                  'ActivityLabel': activity_label_test})

# %%
error_activity_df.head()
# Out:
#         ActivityLabel     Error
# 214377              0  0.051893
# 214378              0  0.052075
# 214379              0  0.051774
# 214380              0  0.052822
# 214381              0  0.052785

# %%
precision, recall, th = precision_recall_curve(error_activity_df.ActivityLabel, error_activity_df.Error, pos_label=1)
plt.figure(figsize=(20, 5))
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
activity_threshold = np.mean(error_activity_df['Error'])
print('Threshold of Activity: {}'.format(activity_threshold))
# Out:
# Threshold of Activity: 0.05304249784229051

# %% [markdown]
# ### Threshold

# %%
plotConfusionMaxtrix(error_activity_df, activity_threshold, variable='Activity', output_dir=args.output_dir, save=True)

# %%
plotOverlapReconstructionError(error_activity_df, variable='Activity', output_dir=args.output_dir, save=True)

# %%
plotReconstructionError(error_activity_df)

# %%
evalScore(error_activity_df, 0.054, variable='Activity')
# Out:
# -------Evaluation of Activity-------
#
#
# --Weighted Evaluation--
# Evaluation of Activity
# Precision: 0.93
# Recall: 0.94
# Fscore: 0.94
#
#
# --Evaluation for each class--
# Normal
# Precision: 0.96
# Recall: 0.97
# Fscore: 0.97
#
#
# Anomaly
# Precision: 0.73
# Recall: 0.62
# Fscore: 0.67

# %%
fpr, tpr, thresholds = roc_curve(error_activity_df.ActivityLabel, error_activity_df.Error, pos_label=1)
roc_auc = auc(fpr, tpr)

#plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig(args.output_dir+'ROC_Act.png')
plt.show();

# %% [markdown]
# ### Argmax

# %%
#evaluate based on classification
predicted_act_df = pd.DataFrame(data=predicted_activity, columns=list(true_act))
predicted_act_label = predicted_act_df.idxmax(axis=1)
true_act_label = true_act.idxmax(axis=1)
predicted_time_label = [0 if a==b else 1 for a, b in zip(true_act_label,predicted_act_label)]

# %%
#plot confusion matrix
LABELS = ['Normal', 'Anomaly']
matrix = confusion_matrix(error_activity_df.ActivityLabel.astype('uint8'), predicted_time_label)
plt.figure(figsize=(7, 7))
sns.heatmap(matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title('Confusion matrix of Activity')
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
score = precision_recall_fscore_support(error_activity_df.ActivityLabel.astype('uint8'), predicted_time_label, average='weighted')
    
print('-------Evaluation of Activity-------')
print('\n')
print('--Weighted Evaluation--')
print('Evaluation')
print('Precision: {:.2f}'.format(score[0]))
print('Recall: {:.2f}'.format(score[1]))
print('Fscore: {:.2f}'.format(score[2]))
print('\n')
score_1 = precision_recall_fscore_support(error_activity_df.ActivityLabel.astype('uint8'), predicted_time_label)
print('--Evaluation for each class--')
print('Normal')
print('Precision: {:.2f}'.format(score_1[0][0]))
print('Recall: {:.2f}'.format(score_1[1][0]))
print('Fscore: {:.2f}'.format(score_1[2][0]))
print('\n')
print('Anomaly')
print('Precision: {:.2f}'.format(score_1[0][1]))
print('Recall: {:.2f}'.format(score_1[1][1]))
print('Fscore: {:.2f}'.format(score_1[2][1]))
# Out:
# -------Evaluation of Activity-------
#
#
# --Weighted Evaluation--
# Evaluation
# Precision: 0.94
# Recall: 0.85
# Fscore: 0.88
#
#
# --Evaluation for each class--
# Normal
# Precision: 1.00
# Recall: 0.84
# Fscore: 0.91
#
#
# Anomaly
# Precision: 0.41
# Recall: 0.98
# Fscore: 0.58

# %%
from sklearn.metrics import accuracy_score
accuracy_score(true_act_label, predicted_act_label)
# Out:
# 0.75482508416452332

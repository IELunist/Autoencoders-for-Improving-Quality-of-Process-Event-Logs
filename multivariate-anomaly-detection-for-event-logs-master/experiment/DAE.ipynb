# %% [markdown]
# This is the implementation of [**Denoising Autoencoder**](http://delivery.acm.org/10.1145/1400000/1390294/p1096-vincent.pdf?ip=118.35.162.43&id=1390294&acc=ACTIVE%20SERVICE&key=0EC22F8658578FE1%2E6E075F2F25AA1826%2E4D4702B0C3E38B35%2E4D4702B0C3E38B35&CFID=1013136076&CFTOKEN=19688859&__acm__=1512370678_e784fe9f2f4167645a6ac749911ba7d6)

# %%
import importlib
import argparse
import os, sys
import argparse
import pandas as pd
import numpy as np
import pickle
import time

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, roc_curve, auc, precision_recall_curve


# %matplotlib inline

# %%
import torch
import torch.utils.data
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
import torch.optim.lr_scheduler
from torch.autograd import Variable
from torchvision import transforms

# %%
sys.path.insert(0, './../utils/')
from utils import *
from models import *

# %%
#Define parser
#name = 'bpi_2013'
#name = 'bpi_2012'
name = 'small_log'
#name = 'large_log'

parser = {
    'train': True,
    'test': True,
    'model_class': 'AE_dropout', #AE_dropout
    'model_name': '',
    'data_dir': '../data/',
    'data_file': name + '.csv',
    'anomaly_pct': 0.1,
    'scaler': 'standardization',
    'input_dir': '../input/{}/'.format(name), 
    'batch_size' : 16,
    'epochs' : 100,
    'no_cuda' : False,
    'seed' : 7,
    'layer1': 100,
    'layer2': 50,
    'lr': 0.001,
    'betas': (0.9, 0.999),   
    'lr_decay': 0.99,
    'noise_factor': 0.25,
}

args = argparse.Namespace(**parser)
args.output_dir = './output/{0}_{1}_{2}/'.format(name, args.anomaly_pct, args.model_class)

# %%
if not os.path.isdir(args.output_dir):
    os.makedirs(args.output_dir)

# %%
args.cuda = not args.no_cuda and torch.cuda.is_available()
kwargs = {'num_workers': 2, 'pin_memory': True} if args.cuda else {}

# %%
torch.manual_seed(args.seed)
if args.cuda:
    torch.cuda.manual_seed(args.seed)

# %%
preprocessed_data_name = os.path.join(args.input_dir, 'preprocessed_data_{}.pkl'.format(args.anomaly_pct))
with open(preprocessed_data_name, 'rb') as f:
    input_train = pickle.load(f)
    input_val = pickle.load(f)
    input_test = pickle.load(f)
    pad_index_train = pickle.load(f)
    pad_index_val = pickle.load(f)
    pad_index_test = pickle.load(f)
    activity_label_test = pickle.load(f)
    time_label_test = pickle.load(f)
    train_case_num = pickle.load(f)
    val_case_num = pickle.load(f)
    test_case_num = pickle.load(f)
    train_row_num = pickle.load(f)
    val_row_num = pickle.load(f)
    test_row_num = pickle.load(f)
    min_value = pickle.load(f)
    max_value = pickle.load(f)
    mean_value = pickle.load(f)
    std_value = pickle.load(f)
    cols = pickle.load(f)
    statistics_storage = pickle.load(f)
    true_time = pickle.load(f)
    true_act = pickle.load(f)
    full_true_time = pickle.load(f)
    full_true_act = pickle.load(f)

# %% [markdown]
# # Load data

# %%
#train
input_trainLoader = torch.utils.data.DataLoader(input_train, batch_size=args.batch_size, shuffle=False, num_workers=2)
pad_index_trainLoader = torch.utils.data.DataLoader(pad_index_train, batch_size=args.batch_size, shuffle=False, num_workers=2)

# %%
#df
normal_df_name = os.path.join(args.input_dir, 'normal_df_{}.csv'.format(args.anomaly_pct))
normal_df = pd.read_csv(normal_df_name)

anomalous_df_name = os.path.join(args.input_dir, 'anomolous_df_{}.csv'.format(args.anomaly_pct))
anomalous_df = pd.read_csv(anomalous_df_name)

#test
caseid_test = normal_df['CaseID'][-test_row_num:]
normal_df_test = normal_df[-test_row_num:]
anomalous_df_test = anomalous_df[-test_row_num:]

# %%
normal_df.head()
# Out:
#    CaseID    Activity    CompleteTimestamp  Duration  CumDuration
# 0       1  Activity A  1970-01-01 09:00:00       0.0          0.0
# 1       1  Activity B  1970-01-01 10:00:00    3600.0       3600.0
# 2       1  Activity C  1970-01-01 11:00:00    3600.0       7200.0
# 3       1  Activity D  1970-01-01 12:00:00    3600.0      10800.0
# 4       1  Activity E  1970-01-01 13:00:00    3600.0      14400.0

# %%
anomalous_df.head()
# Out:
#    CaseID AnomalousActivity  AnomalousCompleteTimestamp  AnomalousDuration  \
# 0       1        Activity A  1970-01-01 09:00:00.000000           0.000000
# 1       1        Activity B  1970-01-01 10:02:46.049539        3766.049539
# 2       1        Activity C  1970-01-01 11:11:25.335178        4285.335178
# 3       1        Activity A  1970-01-01 12:00:00.000000        3600.000000
# 4       1        Activity E  1970-01-01 13:00:00.000000        3600.000000
#
#    AnomalousCumDuration  ActivityLabel  TimeLabel
# 0              0.000000              0          0
# 1           3766.049539              0          1
# 2           7885.335178              0          1
# 3          10800.000000              1          0
# 4          14400.000000              0          0

# %% [markdown]
# # Build model

# %% [markdown]
# ## Define model

# %%
if args.model_class == 'AE':
    model = AE(input_train.shape, args.layer1, args.layer2)
    
if args.model_class == 'AE_dropout':
    model = AE_dropout(input_train.shape, args.layer1, args.layer2)

if args.cuda:
    model.cuda()

# %%
model
# Out:
# AE_dropout (
#   (fc1): Linear (210 -> 100)
#   (fc2): Linear (100 -> 50)
#   (fc3): Linear (50 -> 100)
#   (fc4): Linear (100 -> 210)
#   (dout): Dropout (p = 0.2)
#   (tanh): Tanh ()
# )

# %% [markdown]
# ## Define loss

# %%
def loss_function(recon_x, x, pad_index):
    MSE = F.mse_loss(recon_x*pad_index, x*pad_index, size_average=False) 
    return MSE

# %% [markdown]
# ## Define optimizer

# %%
optimizer = optim.Adam(model.parameters(), lr=args.lr, betas=args.betas)

# %%
#Adjust learning rate per epoch: http://pytorch.org/docs/master/optim.html?highlight=lr_scheduler#torch.optim.lr_scheduler.LambdaLR

lambda1 = lambda epoch: args.lr_decay ** epoch
scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda=[lambda1])

# %% [markdown]
# # Utils

# %%
def save_model(model, epoch, score):
    model_file = os.path.join(args.output_dir, 'model_{}_epoch{}_score{:.4f}.pth'.format(args.model_class, epoch, score))
    torch.save(model.state_dict(), model_file)

# %%
def load_model(model, model_name):
    model_file = os.path.join(args.output_dir, model_name)
    assert os.path.isfile(model_file), 'Error: no model found!'
    model_state = torch.load(model_file)
    model.load_state_dict(model_state)

# %%
def val(model, input_val, pad_index_val):
    model.eval()
    input_val = Variable(torch.Tensor(input_val).float())
    pad_index_val = Variable(torch.Tensor(pad_index_val).float())
    
    if args.cuda:
        input_val = input_val.cuda()
        pad_index_val = pad_index_val.cuda()
    
    recon_val = model(input_val)    
    loss = loss_function(recon_val, input_val, pad_index_val)
    return loss.data[0]/len(input_test.data)

# %% [markdown]
# # Train

# %%
def train(epoch, model, optimizer):
    model.train()
    train_loss = 0
    for batch_idx, (batch_data, batch_index) in enumerate(zip(input_trainLoader, pad_index_trainLoader)):
        
        batch_data = Variable(batch_data.float())
        batch_index = Variable(batch_index.float())
        # Add noise
        batch_data_noise = batch_data + args.noise_factor * Variable(torch.randn(batch_data.size()))

        if args.cuda:
            batch_data = batch_data.cuda()
            batch_data_noise = batch_data_noise.cuda()
            batch_index = batch_index.cuda()
            
        optimizer.zero_grad()
        
        recon_data = model(batch_data_noise)
        
        loss = loss_function(recon_data, batch_data, batch_index)
        
        loss.backward()
        train_loss += loss.data[0]
        optimizer.step()
        
    return train_loss / len(input_trainLoader.dataset)

# %%
if args.train:
    for epoch in range(1, args.epochs + 1):
        init = time.time()
        
        #method 1 scheduler
        scheduler.step()
        
        train_loss = train(epoch, model, optimizer)
        end_train = time.time()
        val_score = val(model, input_val, pad_index_val)
        
        end = time.time()
        print('====> Epoch {} | Train time: {:.4f} ms| End time: {:.4f} ms | Train loss: {:.4f} | Val loss: {:.4f}'.
              format(epoch, (end_train-init)*1000, (end-init)*1000, train_loss, val_score))
else:
    load_model(model, args.model_name)
# Out:
# ====> Epoch 1 | Train time: 520.6661 ms| End time: 545.4950 ms | Train loss: 101.1532 | Val loss: 11.0942
# ====> Epoch 2 | Train time: 393.8251 ms| End time: 417.3241 ms | Train loss: 47.7529 | Val loss: 7.5286
# ====> Epoch 3 | Train time: 317.6808 ms| End time: 341.6998 ms | Train loss: 31.1423 | Val loss: 6.7464
# ====> Epoch 4 | Train time: 308.7862 ms| End time: 335.5920 ms | Train loss: 21.5964 | Val loss: 5.6911
# ====> Epoch 5 | Train time: 311.1029 ms| End time: 334.1959 ms | Train loss: 16.5636 | Val loss: 5.4938
# ====> Epoch 6 | Train time: 393.0261 ms| End time: 420.2390 ms | Train loss: 13.4997 | Val loss: 4.9998
# ====> Epoch 7 | Train time: 437.1531 ms| End time: 466.7320 ms | Train loss: 11.4485 | Val loss: 4.4329
# ====> Epoch 8 | Train time: 409.3590 ms| End time: 435.4341 ms | Train loss: 9.8419 | Val loss: 4.1526
# ====> Epoch 9 | Train time: 316.7710 ms| End time: 339.7419 ms | Train loss: 8.8133 | Val loss: 3.9433
# ====> Epoch 10 | Train time: 380.7490 ms| End time: 403.5151 ms | Train loss: 7.9922 | Val loss: 3.6881
# ====> Epoch 11 | Train time: 317.1270 ms| End time: 343.2341 ms | Train loss: 7.3409 | Val loss: 3.5411
# ====> Epoch 12 | Train time: 430.2990 ms| End time: 455.6520 ms | Train loss: 6.8735 | Val loss: 3.4055
# ====> Epoch 13 | Train time: 397.7849 ms| End time: 428.2119 ms | Train loss: 6.4036 | Val loss: 3.2069
# ====> Epoch 14 | Train time: 415.6282 ms| End time: 442.9040 ms | Train loss: 6.0877 | Val loss: 3.1581
# ====> Epoch 15 | Train time: 419.3890 ms| End time: 447.6061 ms | Train loss: 5.7959 | Val loss: 3.0904
# ====> Epoch 16 | Train time: 409.0910 ms| End time: 434.0229 ms | Train loss: 5.5703 | Val loss: 3.0463
# ====> Epoch 17 | Train time: 352.8411 ms| End time: 382.9310 ms | Train loss: 5.3872 | Val loss: 3.0032
# ====> Epoch 18 | Train time: 443.8000 ms| End time: 472.3661 ms | Train loss: 5.1295 | Val loss: 2.9314
# ====> Epoch 19 | Train time: 433.6610 ms| End time: 463.2361 ms | Train loss: 5.0704 | Val loss: 2.9213
# ====> Epoch 20 | Train time: 423.0139 ms| End time: 448.4410 ms | Train loss: 4.9384 | Val loss: 2.8883
# ====> Epoch 21 | Train time: 374.0058 ms| End time: 402.0250 ms | Train loss: 4.8214 | Val loss: 2.8823
# ====> Epoch 22 | Train time: 393.3249 ms| End time: 415.9238 ms | Train loss: 4.7602 | Val loss: 2.8338
# ====> Epoch 23 | Train time: 323.4291 ms| End time: 347.6381 ms | Train loss: 4.6955 | Val loss: 2.8184
# ====> Epoch 24 | Train time: 445.9641 ms| End time: 470.7379 ms | Train loss: 4.5646 | Val loss: 2.8076
# ====> Epoch 25 | Train time: 360.5351 ms| End time: 398.7231 ms | Train loss: 4.5457 | Val loss: 2.8072
# ====> Epoch 26 | Train time: 425.9701 ms| End time: 454.5600 ms | Train loss: 4.4641 | Val loss: 2.7822
# ====> Epoch 27 | Train time: 363.2140 ms| End time: 389.0460 ms | Train loss: 4.4183 | Val loss: 2.7696
# ====> Epoch 28 | Train time: 364.7089 ms| End time: 390.4281 ms | Train loss: 4.3430 | Val loss: 2.7570
# ====> Epoch 29 | Train time: 347.1191 ms| End time: 374.5060 ms | Train loss: 4.3193 | Val loss: 2.7497
# ====> Epoch 30 | Train time: 391.9790 ms| End time: 418.1371 ms | Train loss: 4.2569 | Val loss: 2.7628
# ====> Epoch 31 | Train time: 352.2470 ms| End time: 374.0201 ms | Train loss: 4.2621 | Val loss: 2.7320
# ====> Epoch 32 | Train time: 387.7611 ms| End time: 407.9542 ms | Train loss: 4.1747 | Val loss: 2.7307
# ====> Epoch 33 | Train time: 326.4060 ms| End time: 350.0879 ms | Train loss: 4.1376 | Val loss: 2.7195
# ====> Epoch 34 | Train time: 360.5149 ms| End time: 389.6999 ms | Train loss: 4.1808 | Val loss: 2.7190
# ====> Epoch 35 | Train time: 341.6188 ms| End time: 398.9408 ms | Train loss: 4.1066 | Val loss: 2.7027
# ====> Epoch 36 | Train time: 373.0130 ms| End time: 398.1230 ms | Train loss: 4.0777 | Val loss: 2.6860
# ====> Epoch 37 | Train time: 377.2221 ms| End time: 404.3219 ms | Train loss: 4.1017 | Val loss: 2.6965
# ====> Epoch 38 | Train time: 329.2360 ms| End time: 355.2480 ms | Train loss: 4.0252 | Val loss: 2.6660
# ====> Epoch 39 | Train time: 380.1398 ms| End time: 405.5688 ms | Train loss: 3.9795 | Val loss: 2.6701
# ====> Epoch 40 | Train time: 352.2871 ms| End time: 377.2531 ms | Train loss: 3.9752 | Val loss: 2.6616
# ====> Epoch 41 | Train time: 331.7149 ms| End time: 359.8108 ms | Train loss: 3.9424 | Val loss: 2.6548
# ====> Epoch 42 | Train time: 339.3760 ms| End time: 366.1420 ms | Train loss: 3.9903 | Val loss: 2.6698
# ====> Epoch 43 | Train time: 359.8778 ms| End time: 383.0640 ms | Train loss: 3.9602 | Val loss: 2.6553
# ====> Epoch 44 | Train time: 361.6600 ms| End time: 388.1178 ms | Train loss: 3.9267 | Val loss: 2.6388
# ====> Epoch 45 | Train time: 502.9669 ms| End time: 533.0269 ms | Train loss: 3.9158 | Val loss: 2.6403
# ====> Epoch 46 | Train time: 359.0581 ms| End time: 384.2390 ms | Train loss: 3.9041 | Val loss: 2.6400
# ====> Epoch 47 | Train time: 340.5550 ms| End time: 371.5379 ms | Train loss: 3.9153 | Val loss: 2.6206
# ====> Epoch 48 | Train time: 382.9579 ms| End time: 403.4700 ms | Train loss: 3.8801 | Val loss: 2.6090
# ====> Epoch 49 | Train time: 320.5428 ms| End time: 341.4829 ms | Train loss: 3.8413 | Val loss: 2.6222
# ====> Epoch 50 | Train time: 324.3279 ms| End time: 345.9208 ms | Train loss: 3.8424 | Val loss: 2.6230
# ====> Epoch 51 | Train time: 318.2008 ms| End time: 340.8029 ms | Train loss: 3.8293 | Val loss: 2.6212
# ====> Epoch 52 | Train time: 447.7861 ms| End time: 477.3550 ms | Train loss: 3.8054 | Val loss: 2.6002
# ====> Epoch 53 | Train time: 428.6928 ms| End time: 455.4219 ms | Train loss: 3.7595 | Val loss: 2.6022
# ====> Epoch 54 | Train time: 382.6621 ms| End time: 407.9199 ms | Train loss: 3.8180 | Val loss: 2.6171
# ====> Epoch 55 | Train time: 428.6079 ms| End time: 455.3590 ms | Train loss: 3.7585 | Val loss: 2.5995
# ====> Epoch 56 | Train time: 426.8489 ms| End time: 455.5769 ms | Train loss: 3.7867 | Val loss: 2.5961
# ====> Epoch 57 | Train time: 438.1659 ms| End time: 465.4949 ms | Train loss: 3.7446 | Val loss: 2.5929
# ====> Epoch 58 | Train time: 442.3101 ms| End time: 467.9890 ms | Train loss: 3.6949 | Val loss: 2.5827
# ====> Epoch 59 | Train time: 458.2379 ms| End time: 486.2788 ms | Train loss: 3.7336 | Val loss: 2.5729
# ====> Epoch 60 | Train time: 480.0529 ms| End time: 509.3951 ms | Train loss: 3.7168 | Val loss: 2.5729
# ====> Epoch 61 | Train time: 412.1299 ms| End time: 442.8959 ms | Train loss: 3.6936 | Val loss: 2.5673
# ====> Epoch 62 | Train time: 389.6189 ms| End time: 416.1370 ms | Train loss: 3.7032 | Val loss: 2.5687
# ====> Epoch 63 | Train time: 473.6898 ms| End time: 498.8558 ms | Train loss: 3.6732 | Val loss: 2.5739
# ====> Epoch 64 | Train time: 418.1340 ms| End time: 447.1891 ms | Train loss: 3.6599 | Val loss: 2.5674
# ====> Epoch 65 | Train time: 439.4259 ms| End time: 468.6210 ms | Train loss: 3.6751 | Val loss: 2.5612
# ====> Epoch 66 | Train time: 378.3720 ms| End time: 401.8679 ms | Train loss: 3.6645 | Val loss: 2.5724
# ====> Epoch 67 | Train time: 384.5749 ms| End time: 414.3951 ms | Train loss: 3.6458 | Val loss: 2.5654
# ====> Epoch 68 | Train time: 350.2171 ms| End time: 373.9622 ms | Train loss: 3.6079 | Val loss: 2.5454
# ====> Epoch 69 | Train time: 309.2599 ms| End time: 332.7138 ms | Train loss: 3.5941 | Val loss: 2.5478
# ====> Epoch 70 | Train time: 311.4510 ms| End time: 338.2490 ms | Train loss: 3.6373 | Val loss: 2.5425
# ====> Epoch 71 | Train time: 350.2800 ms| End time: 381.0301 ms | Train loss: 3.6004 | Val loss: 2.5432
# ====> Epoch 72 | Train time: 396.2240 ms| End time: 417.4218 ms | Train loss: 3.5603 | Val loss: 2.5359
# ====> Epoch 73 | Train time: 347.5890 ms| End time: 374.0530 ms | Train loss: 3.6088 | Val loss: 2.5268
# ====> Epoch 74 | Train time: 355.3050 ms| End time: 378.4518 ms | Train loss: 3.5617 | Val loss: 2.5182
# ====> Epoch 75 | Train time: 350.7180 ms| End time: 374.7840 ms | Train loss: 3.5646 | Val loss: 2.5274
# ====> Epoch 76 | Train time: 324.9171 ms| End time: 343.1060 ms | Train loss: 3.5495 | Val loss: 2.5193
# ====> Epoch 77 | Train time: 329.9341 ms| End time: 354.0061 ms | Train loss: 3.5640 | Val loss: 2.5151
# ====> Epoch 78 | Train time: 358.8839 ms| End time: 383.1968 ms | Train loss: 3.5486 | Val loss: 2.5156
# ====> Epoch 79 | Train time: 347.8000 ms| End time: 371.9521 ms | Train loss: 3.5087 | Val loss: 2.5074
# ====> Epoch 80 | Train time: 353.1969 ms| End time: 379.7369 ms | Train loss: 3.5271 | Val loss: 2.5033
# ====> Epoch 81 | Train time: 332.3460 ms| End time: 354.9840 ms | Train loss: 3.5092 | Val loss: 2.5130
# ====> Epoch 82 | Train time: 353.7230 ms| End time: 377.1911 ms | Train loss: 3.5070 | Val loss: 2.5009
# ====> Epoch 83 | Train time: 318.2740 ms| End time: 337.5950 ms | Train loss: 3.5081 | Val loss: 2.5024
# ====> Epoch 84 | Train time: 323.2331 ms| End time: 349.8690 ms | Train loss: 3.5017 | Val loss: 2.4966
# ====> Epoch 85 | Train time: 343.9109 ms| End time: 367.0001 ms | Train loss: 3.4818 | Val loss: 2.5031
# ====> Epoch 86 | Train time: 327.3721 ms| End time: 349.1461 ms | Train loss: 3.4947 | Val loss: 2.4912
# ====> Epoch 87 | Train time: 325.9120 ms| End time: 343.9569 ms | Train loss: 3.4773 | Val loss: 2.4833
# ====> Epoch 88 | Train time: 345.4750 ms| End time: 369.5140 ms | Train loss: 3.4765 | Val loss: 2.4801
# ====> Epoch 89 | Train time: 341.6090 ms| End time: 363.6801 ms | Train loss: 3.4335 | Val loss: 2.4778
# ====> Epoch 90 | Train time: 332.5171 ms| End time: 358.8781 ms | Train loss: 3.4608 | Val loss: 2.4804
# ====> Epoch 91 | Train time: 329.2630 ms| End time: 352.5529 ms | Train loss: 3.4380 | Val loss: 2.4747
# ====> Epoch 92 | Train time: 348.3291 ms| End time: 375.8290 ms | Train loss: 3.4247 | Val loss: 2.4789
# ====> Epoch 93 | Train time: 347.1131 ms| End time: 373.5540 ms | Train loss: 3.4358 | Val loss: 2.4701
# ====> Epoch 94 | Train time: 333.2179 ms| End time: 359.2329 ms | Train loss: 3.4407 | Val loss: 2.4668
# ====> Epoch 95 | Train time: 332.6521 ms| End time: 354.7921 ms | Train loss: 3.4170 | Val loss: 2.4655
# ====> Epoch 96 | Train time: 347.6489 ms| End time: 370.6081 ms | Train loss: 3.3998 | Val loss: 2.4552
# ====> Epoch 97 | Train time: 345.2189 ms| End time: 373.2700 ms | Train loss: 3.4257 | Val loss: 2.4578
# ====> Epoch 98 | Train time: 330.4331 ms| End time: 353.9979 ms | Train loss: 3.4037 | Val loss: 2.4558
# ====> Epoch 99 | Train time: 332.2170 ms| End time: 355.2320 ms | Train loss: 3.4192 | Val loss: 2.4589
# ====> Epoch 100 | Train time: 327.6608 ms| End time: 351.5379 ms | Train loss: 3.3643 | Val loss: 2.4538

# %% [markdown]
# # Predict

# %%
if args.test:
    input_test = Variable(torch.Tensor(input_test).float())
    if args.cuda:
        input_test = input_test.cuda()
    
    print('Predicting...')
    recon_test = model(input_test)
    
    print('Separating prediction ...')
    predicted_time, predicted_activity = getPrediction(recon_test, pad_index_test)
    
    print('Done!')
# Out:
# Predicting...
# Separating prediction ...
# Done!

# %% [markdown]
# # Evaluate

# %% [markdown]
# ## Time

# %%
#Fix predicted time
time_df = pd.DataFrame({'CaseID': caseid_test,
                        'PredictedTime': predicted_time})

groupByCase = time_df.groupby(['CaseID'])
fixed_time_df = pd.DataFrame(columns=list(time_df))

for case, group in groupByCase:
    group.iloc[0, 1] = -mean_value/std_value
    fixed_time_df = fixed_time_df.append(group)
# Out:
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
fixed_time_df.head()
# Out:
#       CaseID  PredictedTime
# 22400   1601      -2.057711
# 22401   1601      -1.605473
# 22402   1601      -1.157700
# 22403   1601      -0.714902
# 22404   1601      -0.259419

# %%
fixed_predicted_time = fixed_time_df['PredictedTime']

# %%
error = np.abs(true_time - fixed_predicted_time)
error_time_df = pd.DataFrame({'Error': error,
                              'TimeLabel': time_label_test})

# %%
precision, recall, th = precision_recall_curve(error_time_df.TimeLabel, error_time_df.Error, pos_label=1)
plt.figure(figsize=(20, 5))
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
time_threshold = np.mean(error_time_df['Error'])
print('Threshold of Time: {}'.format(time_threshold))
# Out:
# Threshold of Time: 0.053569730649479265

# %%
plotOverlapReconstructionError(error_time_df, variable='Time', output_dir=args.output_dir, save=True)

# %%
plotReconstructionError(error_time_df, variable='Time')

# %%
plotConfusionMaxtrix(error_time_df, threshold=time_threshold, variable='Time', output_dir=args.output_dir, save=True)

# %%
evalScore(error_time_df, threshold=time_threshold, variable='Time')
# Out:
# -------Evaluation of Time-------
#
#
# --Weighted Evaluation--
# Evaluation of Time
# Precision: 0.92
# Recall: 0.78
# Fscore: 0.83
#
#
# --Evaluation for each class--
# Normal
# Precision: 0.98
# Recall: 0.77
# Fscore: 0.87
#
#
# Anomaly
# Precision: 0.28
# Recall: 0.88
# Fscore: 0.43

# %%
fpr, tpr, thresholds = roc_curve(error_time_df.TimeLabel, error_time_df.Error, pos_label=1)
roc_auc = auc(fpr, tpr)

#plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig(args.output_dir + 'ROC_time.png')
plt.show();

# %%
#get submission
if args.scaler == 'standardization':
    inverse_scaled_time = [x*std_value+mean_value for x in fixed_predicted_time]
else:
    inverse_scaled_time = [x*(max_value-min_value)+min_value for x in fixed_predicted_time]
    
predicted_time_label_test = [1 if e > time_threshold else 0 for e in error_time_df.Error.values]

submission_time = pd.DataFrame({'AnomalousDuration': anomalous_df_test['AnomalousDuration'].copy(),
                                'Activity': normal_df_test['Activity'].copy(),
                                'AnomalousCumDuration': anomalous_df_test['AnomalousCumDuration'].copy(),
                                'PredictedCumDuration': inverse_scaled_time,
                                'TimeLabel': time_label_test,
                                'PredictedTimeLabel': predicted_time_label_test})

# %%
submission_time.head()
# Out:
#          Activity  AnomalousCumDuration  AnomalousDuration  \
# 22400  Activity A                   0.0                0.0
# 22401  Activity B                3600.0             3600.0
# 22402  Activity C                7200.0             3600.0
# 22403  Activity D               10800.0             3600.0
# 22404  Activity E               14400.0             3600.0
#
#        PredictedCumDuration  PredictedTimeLabel TimeLabel
# 22400              0.000000                   0         0
# 22401           3666.184665                   0         0
# 22402           7296.166295                   0         0
# 22403          10885.817157                   0         0
# 22404          14578.304807                   0         0

# %%
groupByActivity = submission_time.groupby(['Activity'])

for act, group in groupByActivity:
    plotDurationofPredictedTimeLabel(act, group, statistics_storage, args.output_dir, True)

# %%
submission_time.head()
# Out:
#          Activity  AnomalousCumDuration  AnomalousDuration  \
# 22400  Activity A                   0.0                0.0
# 22401  Activity B                3600.0             3600.0
# 22402  Activity C                7200.0             3600.0
# 22403  Activity D               10800.0             3600.0
# 22404  Activity E               14400.0             3600.0
#
#        PredictedCumDuration  PredictedTimeLabel TimeLabel
# 22400              0.000000                   0         0
# 22401           3666.184665                   0         0
# 22402           7296.166295                   0         0
# 22403          10885.817157                   0         0
# 22404          14578.304807                   0         0

# %%
act_list = [i for i in submission_time['Activity'].unique()]
false_positive_df = submission_time[(submission_time['PredictedTimeLabel']== 1)&(submission_time['TimeLabel']== 0)]
false_negative_df = submission_time[(submission_time['PredictedTimeLabel']== 0)&(submission_time['TimeLabel']== 1)]

for act in act_list:
    plotFalseDuration(false_positive_df, false_negative_df, act, statistics_storage)

# %% [markdown]
# ## Activity

# %%
#error = np.mean(np.power(true_act - predicted_activity, 2), axis = 1)
error = np.mean(np.abs(true_act - predicted_activity), axis = 1)
error_activity_df = pd.DataFrame({'Error': error,
                                  'ActivityLabel': activity_label_test})

# %%
error_activity_df.head()
# Out:
#        ActivityLabel     Error
# 22400              0  0.120958
# 22401              0  0.120975
# 22402              0  0.119536
# 22403              0  0.119825
# 22404              0  0.119582

# %%
precision, recall, th = precision_recall_curve(error_activity_df.ActivityLabel, error_activity_df.Error, pos_label=1)
plt.figure(figsize=(20, 5))
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
activity_threshold = np.mean(error_activity_df['Error'])
print('Threshold of Activity: {}'.format(activity_threshold))
# Out:
# Threshold of Activity: 0.12145132851592093

# %% [markdown]
# ### Threshold

# %%
plotConfusionMaxtrix(error_activity_df, activity_threshold, variable='Activity', output_dir=args.output_dir, save=True)

# %%
plotOverlapReconstructionError(error_activity_df, variable='Activity', output_dir=args.output_dir, save=True)

# %%
plotReconstructionError(error_activity_df)

# %%
evalScore(error_activity_df, 0.054, variable='Activity')
# Out:
# -------Evaluation of Activity-------
#
#
# --Weighted Evaluation--
# Evaluation of Activity
# Precision: 0.01
# Recall: 0.10
# Fscore: 0.02
#
#
# --Evaluation for each class--
# Normal
# Precision: 0.00
# Recall: 0.00
# Fscore: 0.00
#
#
# Anomaly
# Precision: 0.10
# Recall: 1.00
# Fscore: 0.19
# /Users/hoangnguyen/miniconda3/envs/pydata/lib/python3.5/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
fpr, tpr, thresholds = roc_curve(error_activity_df.ActivityLabel, error_activity_df.Error, pos_label=1)
roc_auc = auc(fpr, tpr)

#plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.savefig(args.output_dir+'ROC_Act.png')
plt.show();

# %% [markdown]
# ### Argmax

# %%
#evaluate based on classification
predicted_act_df = pd.DataFrame(data=predicted_activity, columns=list(true_act))
predicted_act_label = predicted_act_df.idxmax(axis=1)
true_act_label = true_act.idxmax(axis=1)
predicted_time_label = [0 if a==b else 1 for a, b in zip(true_act_label,predicted_act_label)]

# %%
#plot confusion matrix
LABELS = ['Normal', 'Anomaly']
matrix = confusion_matrix(error_activity_df.ActivityLabel.astype('uint8'), predicted_time_label)
plt.figure(figsize=(7, 7))
sns.heatmap(matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
plt.title('Confusion matrix of Activity')
plt.ylabel('True class')
plt.xlabel('Predicted class')
plt.show()

# %%
score = precision_recall_fscore_support(error_activity_df.ActivityLabel.astype('uint8'), predicted_time_label, average='weighted')
    
print('-------Evaluation of Activity-------')
print('\n')
print('--Weighted Evaluation--')
print('Evaluation')
print('Precision: {:.2f}'.format(score[0]))
print('Recall: {:.2f}'.format(score[1]))
print('Fscore: {:.2f}'.format(score[2]))
print('\n')
score_1 = precision_recall_fscore_support(error_activity_df.ActivityLabel.astype('uint8'), predicted_time_label)
print('--Evaluation for each class--')
print('Normal')
print('Precision: {:.2f}'.format(score_1[0][0]))
print('Recall: {:.2f}'.format(score_1[1][0]))
print('Fscore: {:.2f}'.format(score_1[2][0]))
print('\n')
print('Anomaly')
print('Precision: {:.2f}'.format(score_1[0][1]))
print('Recall: {:.2f}'.format(score_1[1][1]))
print('Fscore: {:.2f}'.format(score_1[2][1]))
# Out:
# -------Evaluation of Activity-------
#
#
# --Weighted Evaluation--
# Evaluation
# Precision: 1.00
# Recall: 1.00
# Fscore: 1.00
#
#
# --Evaluation for each class--
# Normal
# Precision: 1.00
# Recall: 1.00
# Fscore: 1.00
#
#
# Anomaly
# Precision: 1.00
# Recall: 0.98
# Fscore: 0.99

# %%
from sklearn.metrics import accuracy_score
accuracy_score(true_act_label, predicted_act_label)
# Out:
# 0.89714285714285713
